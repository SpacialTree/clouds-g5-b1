# %%
from spectral_cube import SpectralCube
from pvextractor import extract_pv_slice, Path
import pylab as pl
import numpy as np
from astropy.visualization import quantity_support
from astropy import units as u
from astropy import wcs
from matplotlib.colors import LogNorm
from astropy.visualization.stretch import SinhStretch
from astropy.visualization import simple_norm
import matplotlib.pyplot as plt
from astropy.utils import data
from pvextractor.gui import PVSlicer
#from spectral_cube import SpectralCube
# Out:
# fatal: detected dubious ownership in repository at '/blue/adamginsburg/adamginsburg/repos/dask'
# To add an exception for this directory, call:
#
# 	git config --global --add safe.directory /blue/adamginsburg/adamginsburg/repos/dask

# %%
#help(pvextractor)
print('test')
# Out:
# test

# %%
#cube_12CO = SpectralCube.read('/orange/adamginsburg/cmz/g5/G5/sum/spw17_12CO/g5.12CO.spw17.im', format='casa').with_spectral_unit(u.km / u.s, velocity_convention='radio')
#cube_13CO = SpectralCube.read('/orange/adamginsburg/cmz/g5/G5/sum/spw29_13CO/g5.13CO.spw29.im', format='casa').with_spectral_unit(u.km / u.s, velocity_convention='radio')
#cube_C18O = SpectralCube.read('/orange/adamginsburg/cmz/g5/G5/sum/spw31_C18O/g5.C18O.spw31.im', format='casa').with_spectral_unit(u.km / u.s, velocity_convention='radio')

#cube_CH3OH = SpectralCube.read('/orange/adamginsburg/cmz/g5/G5/sum/spw21_CH3OH/g5.CH3OH.spw21.im/', format='casa').with_spectral_unit(u.km / u.s, velocity_convention='radio')
#cube_SiO = SpectralCube.read('/orange/adamginsburg/cmz/g5/G5/sum/spw27_SiO/g5.SiO.spw27.im/', format='casa').with_spectral_unit(u.km / u.s, velocity_convention='radio')
#cube_H2CO_spw23 = SpectralCube.read('/orange/adamginsburg/cmz/g5/G5/sum/spw23_H2CO/g5.H2CO.spw23.im/', format='casa').with_spectral_unit(u.km / u.s, velocity_convention='radio')
#cube_H2CO_spw25 = SpectralCube.read('/orange/adamginsburg/cmz/g5/G5/sum/spw25_H2CO/g5.H2CO.spw25.im/', format='casa').with_spectral_unit(u.km / u.s, velocity_convention='radio')
#cube_OCS = SpectralCube.read('/orange/adamginsburg/cmz/g5/G5/sum/', format='casa').with_spectral_unit(u.km / u.s, velocity_convention='radio')

#cube_12CO = SpectralCube.read('/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.12CO.spw17.fits')

#cube=cube.with_spectral_unit(u.km / u.s, velocity_convention='radio')

# %%
a_fixednames =['/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.12CO.spw17.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.Ha.spw19.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.CH3OH.spw21.fits',
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.H2CO.spw23.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.H2CO.spw25.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.SiO.spw27.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.13CO.spw29.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.C18O.spw31.fits' 
               ]

cube_17 = SpectralCube.read(a_fixednames[0]).with_spectral_unit(u.km / u.second, velocity_convention='radio')
cube_21 = SpectralCube.read(a_fixednames[2]).with_spectral_unit(u.km / u.second, velocity_convention='radio')
cube_23 = SpectralCube.read(a_fixednames[3]).with_spectral_unit(u.km / u.second, velocity_convention='radio')
cube_25 = SpectralCube.read(a_fixednames[4]).with_spectral_unit(u.km / u.second, velocity_convention='radio')
cube_27 = SpectralCube.read(a_fixednames[5]).with_spectral_unit(u.km / u.second, velocity_convention='radio')
cube_29 = SpectralCube.read(a_fixednames[6]).with_spectral_unit(u.km / u.second, velocity_convention='radio')
cube_31 = SpectralCube.read(a_fixednames[7]).with_spectral_unit(u.km / u.second, velocity_convention='radio')

# %%
#cube_17.shape
#cube_21.shape
#cube_23.shape
#cube_25.shape
#cube_27.shape
#cube_29.shape
#cube_31.shape

# %%
'''
pv_12CO = PVSlicer(cube_12CO)
pv_13CO = PVSlicer(cube_13CO)
pv_C18O = PVSlicer(cube_C18O)

pv_CH3OH = PVSlicer(cube_CH3OH)
pv_SiO = PVSlicer(cube_SiO)
pv_H2CO_spw23 = PVSlicer(cube_H2CO_spw23)
pv_H2CO_spw25 = PVSlicer(cube_H2CO_spw25)
'''

#path = Path([(0., 0.), (10., 10.)], width=0.5)

#pl.imshow(cube[25].value, origin='lower')
# Out:
# '\npv_12CO = PVSlicer(cube_12CO)\npv_13CO = PVSlicer(cube_13CO)\npv_C18O = PVSlicer(cube_C18O)\n\npv_CH3OH = PVSlicer(cube_CH3OH)\npv_SiO = PVSlicer(cube_SiO)\npv_H2CO_spw23 = PVSlicer(cube_H2CO_spw23)\npv_H2CO_spw25 = PVSlicer(cube_H2CO_spw25)\n'

# %%
#path = Path([(2,30),(268,30)], width = 45.)
#path = Path([(29, 248),(160,19)], width=40.)
#path = Path([(90,15),(155,50)], width=8)
path = Path([(130,55),(190,15)], width=8)
ax = pl.subplot(111, projection=cube_17.wcs.celestial)
mom0 = cube_25.moment0()
mom1 = cube_25.moment1()
mom1 = mom1/(mom0>(1.0*u.K*u.km/u.second))
ax.imshow(mom1.value)
path.show_on_axis(ax, spacing=1, color='r')
# Out:
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/_moments.py:168: RuntimeWarning: invalid value encountered in divide
#   return (np.nansum(data * pix_cen, axis=axis) /
# /blue/adamginsburg/adamginsburg/repos/astropy/astropy/units/quantity.py:674: RuntimeWarning: divide by zero encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/savannahgramze/.local/lib/python3.9/site-packages/pvextractor-0.3.dev33+gac7db5e-py3.9.egg/pvextractor/geometry/path.py:262: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   patches.append(MPLPolygon(list(zip(poly.x, poly.y)), **kwargs))

# %%
pvdiagram_alt_29 = extract_pv_slice(cube=cube_29, path=path, spacing=1)
#aspect = 0.05
aspect = 0.1
#plot_position_velocity(pvdiagram_alt_29, aspect)

# %%
#pvdiagram_12CO = extract_pv_slice(cube=cube_12CO, path=path, spacing=1)


#pvdiagram_13CO = extract_pv_slice(cube=cube_13CO, path=path, spacing=1)
#pvdiagram_C18O = extract_pv_slice(cube=cube_C18O, path=path, spacing=1)

#pvdiagram_CH3OH = extract_pv_slice(cube=cube_CH3OH, path=path, spacing=1)
#pvdiagram_SiO = extract_pv_slice(cube=cube_SiO, path=path, spacing=1)
#pvdiagram_H2CO_spw23 = extract_pv_slice(cube=cube_H2CO_spw23, path=path, spacing=1)
#pvdiagram_H2CO_spw25 = extract_pv_slice(cube=cube_H2CO_spw25, path=path, spacing=1)

#pvdiagram

# %%
#2 * u.arcmin

#pixelarea

# %%
#np.sqrt(pixelarea)*cube.shape[1]

# %%
#2*u.arcmin / np.sqrt(pixelarea)

# %%
cube_17.shape
# Out:
# (2048, 63, 274)

# %%
def plot_position_velocity(pvdiagram, aspect):
    norm = simple_norm(pvdiagram.data, 'asinh')
    fig = pl.figure(figsize=(6,6))
    ax = pl.subplot(111, projection=wcs.WCS(pvdiagram.header))
    
    #im = ax.imshow(pvdiagram.data, norm=norm, cmap='afmhot')
    im = ax.imshow(pvdiagram.data, norm=norm, cmap='inferno')
    #im = ax.imshow(pvdiagram.data, norm=norm)
    
    ax0 = ax.coords[0]
    ax0.set_format_unit(u.arcmin)
    ax1 = ax.coords[1]
    ax1.set_format_unit(u.km/u.s)
    ax.set_ylabel("Velocity [km/s]")
    #ax.set_xlabel("Offset in Longtitude from $\ell=5.48^{\circ}$ [arcmin]")
    ax.set_xlabel("Offset in Longitude from $\ell=5.48^{\circ}$ [arcmin]")
    ax.set_aspect(aspect)
    cb = pl.colorbar(mappable=im)
    #cb.set_label("Brightness Temperature [K]")
    cb.set_label("K")
    #cb.set_label(pvdiagram.unit)
    #pl.tight_layout()

# %%
def plot_maxpv(cube, aspect):
    posv = cube.max(axis=1)#np.max(cube_27.unitless, axis=1)

    pl.figure(figsize=(6,6))
    ww = wcs.WCS(posv.header)
    ax = pl.subplot(111, projection=ww)
    norm = simple_norm(posv.data, 'asinh')
    im = ax.imshow(posv.data, norm=norm)
    
    ax0 = ax.coords[0]
    ax0.set_format_unit(u.arcmin)
    ax1 = ax.coords[1]
    ax1.set_format_unit(u.km/u.s)
    ax.set_ylabel("Velocity [km/s]")
    ax.set_xlabel("Offset in Longtitude from $\ell=5.48^{\circ}$ [arcmin]")
    cb = pl.colorbar(mappable=im)
    cb.set_label(cube.unit)
    
    ax.set_aspect(aspect)

# %%
cube = cube_17
ww = wcs.WCS(cube.header)
pixelarea = ww.proj_plane_pixel_area().to(u.arcmin**2,equivalencies=u.dimensionless_angles())
path = Path([(2,cube.shape[1]/2.),(cube.shape[2]-2,cube.shape[1]/2.)], width = 2*u.arcmin / np.sqrt(pixelarea))
pvdiagram_17 = extract_pv_slice(cube=cube, path=path, spacing=1)

# %%
max_pv = np.max(cube_17, axis=1)
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2aec77ffc670>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: All-NaN slice encountered
#   out = function(self._get_filled_data(fill=fill,
# WARNING: WCSWarning: Slicing across a celestial axis results in an invalid WCS, so the celestial projection (TAN) is being removed.  The WCS indices being kept were [0 2]. [spectral_cube.wcs_utils]

# %%
plt.imshow(max_pv.data, aspect=0.2)
plt.colorbar()

# %%
aspect = 0.2
plot_position_velocity(pvdiagram_17, aspect)
plt.text(10, 50, '$^{12}$CO (2-1)', color='white', fontweight='bold', fontsize='large')
#pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_inferno_12CO.pdf',bbox_inches='tight')
pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_afmhot_12CO.png',bbox_inches='tight', dpi=200)
pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_12CO.pdf',bbox_inches='tight')

# %%
plot_maxpv(cube_17, 0.2)
plt.text(10, 50, '$^{12}$CO (2-1)', color='white', fontweight='bold', fontsize='large')
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2aec77ffc670>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: All-NaN slice encountered
#   out = function(self._get_filled_data(fill=fill,
# WARNING: WCSWarning: Slicing across a celestial axis results in an invalid WCS, so the celestial projection (TAN) is being removed.  The WCS indices being kept were [0 2]. [spectral_cube.wcs_utils]
# Text(10, 50, '$^{12}$CO (2-1)')

# %%
cube = cube_21.with_spectral_unit(u.km/u.second, velocity_convention='radio', rest_value=218.324711 * u.GHz)
ww = wcs.WCS(cube.header)
pixelarea = ww.proj_plane_pixel_area().to(u.arcmin**2,equivalencies=u.dimensionless_angles())
path = Path([(2,cube.shape[1]/2.),(cube.shape[2]-2,cube.shape[1]/2.)], width = 2*u.arcmin / np.sqrt(pixelarea))
pvdiagram_21 = extract_pv_slice(cube=cube, path=path, spacing=1)

# %%
aspect = 0.75
plot_position_velocity(pvdiagram_21, aspect)
plt.text(10, 420, 'H$_2$CO \n(3$_{03}$-2$_{02}$)', color='white', fontweight='bold', fontsize='large')
plt.text(160, 150, 'CH$_3$OH \n(4$_{22}$-3$_{12}$)', color='white', fontweight='bold', fontsize='large')
plt.text(160, 80, 'H$_2$CO \n(3$_{22}$-2$_{21}$)', color='white', fontweight='bold', fontsize='large')

plt.arrow(60, 440, 20, 5, head_width=10, head_length=10, color='white')
plt.arrow(160, 150, -20, 5, head_width=10, head_length=10, color='white')
plt.arrow(160, 80, -20, 5, head_width=10, head_length=10, color='white')

pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_HC3N.pdf',bbox_inches='tight')
pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_HC3N.png',bbox_inches='tight', dpi=200)

# %%
plot_maxpv(cube_21.with_spectral_unit(u.km/u.second, velocity_convention='radio', rest_value=218.324711 * u.GHz), 0.75)
plt.text(10, 420, 'H$_2$CO \n(3$_{03}$-2$_{02}$)', color='white', fontweight='bold', fontsize='large')
plt.text(160, 150, 'CH$_3$OH \n(4$_{22}$-3$_{12}$)', color='white', fontweight='bold', fontsize='large')
plt.text(160, 80, 'H$_2$CO \n(3$_{22}$-2$_{21}$)', color='white', fontweight='bold', fontsize='large')
plt.arrow(60, 440, 20, 5, head_width=10, head_length=10, color='white')
plt.arrow(160, 150, -20, 5, head_width=10, head_length=10, color='white')
plt.arrow(160, 80, -20, 5, head_width=10, head_length=10, color='white')
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2aec77ffc670>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: All-NaN slice encountered
#   out = function(self._get_filled_data(fill=fill,
# WARNING: WCSWarning: Slicing across a celestial axis results in an invalid WCS, so the celestial projection (TAN) is being removed.  The WCS indices being kept were [0 2]. [spectral_cube.wcs_utils]

# %%
cube.spectral_slab(50*u.km/u.second,140*u.km/u.second).moment0().quicklook()
# Out:
# INFO: Auto-setting vmin to -7.716e-02 [aplpy.core]
# INFO: Auto-setting vmax to  8.819e-02 [aplpy.core]

# %%
cube = cube_23
ww = wcs.WCS(cube.header)
pixelarea = ww.proj_plane_pixel_area().to(u.arcmin**2,equivalencies=u.dimensionless_angles())
path = Path([(2,cube.shape[1]/2.),(cube.shape[2]-2,cube.shape[1]/2.)], width = 2*u.arcmin / np.sqrt(pixelarea))
pvdiagram_23 = extract_pv_slice(cube=cube, path=path, spacing=1)

# %%
aspect = 0.75
plot_position_velocity(pvdiagram_23, aspect)
plt.text(160, 330, 'H$_2$CO \n(3$_{21}$-2$_{20}$)', color='white', fontweight='bold', fontsize='large')
plt.arrow(160, 330, -20, 25, head_width=10, head_length=10, color='white')
plt.arrow(200, 320, 15, -45, head_width=10, head_length=10, color='white')

plt.text(160, 80, 'OCS \n(18-17)', color='white', fontweight='bold', fontsize='large')
plt.arrow(160, 80, -20, 5, head_width=10, head_length=10, color='white')


pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_H2CO_spw23.pdf',bbox_inches='tight')
pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_H2CO_spw23.png',bbox_inches='tight', dpi=200)

# %%
plot_maxpv(cube_23, 0.75)
plt.text(160, 330, 'H$_2$CO \n(3$_{21}$-2$_{20}$)', color='white', fontweight='bold', fontsize='large')
plt.arrow(160, 330, -20, 25, head_width=10, head_length=10, color='white')
plt.arrow(200, 320, 15, -45, head_width=10, head_length=10, color='white')

plt.text(160, 80, 'OCS \n(18-17)', color='white', fontweight='bold', fontsize='large')
plt.arrow(160, 80, -20, 5, head_width=10, head_length=10, color='white')
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2aec77ffc670>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: All-NaN slice encountered
#   out = function(self._get_filled_data(fill=fill,
# WARNING: WCSWarning: Slicing across a celestial axis results in an invalid WCS, so the celestial projection (TAN) is being removed.  The WCS indices being kept were [0 2]. [spectral_cube.wcs_utils]

# %%
cube = cube_25
ww = wcs.WCS(cube.header)
pixelarea = ww.proj_plane_pixel_area().to(u.arcmin**2,equivalencies=u.dimensionless_angles())
path = Path([(2,cube.shape[1]/2.),(cube.shape[2]-2,cube.shape[1]/2.)], width = 2*u.arcmin / np.sqrt(pixelarea))
pvdiagram_25 = extract_pv_slice(cube=cube, path=path, spacing=1)

# %%
aspect = 0.75
plot_position_velocity(pvdiagram_25, aspect)
plt.text(10, 30, 'H$_2$CO (3$_{03}$-2$_{02}$)', color='white', fontweight='bold', fontsize='large')

pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_H2CO_spw25.pdf',bbox_inches='tight')
pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_H2CO_spw25.png',bbox_inches='tight', dpi=200)

# %%
plot_maxpv(cube_25, 0.75)
plt.text(10, 30, 'H$_2$CO (3$_{03}$-2$_{02}$)', color='white', fontweight='bold', fontsize='large')
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2aec77ffc670>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: All-NaN slice encountered
#   out = function(self._get_filled_data(fill=fill,
# WARNING: WCSWarning: Slicing across a celestial axis results in an invalid WCS, so the celestial projection (TAN) is being removed.  The WCS indices being kept were [0 2]. [spectral_cube.wcs_utils]
# Text(10, 30, 'H$_2$CO (3$_{03}$-2$_{02}$)')

# %%
cube = cube_27
ww = wcs.WCS(cube.header)
pixelarea = ww.proj_plane_pixel_area().to(u.arcmin**2,equivalencies=u.dimensionless_angles())
path = Path([(2,cube.shape[1]/2.),(cube.shape[2]-2,cube.shape[1]/2.)], width = 2*u.arcmin / np.sqrt(pixelarea))
pvdiagram_27 = extract_pv_slice(cube=cube, path=path, spacing=1)

# %%
aspect = 0.75
plot_position_velocity(pvdiagram_27, aspect)
plt.text(10, 30, 'SiO (5-4)', color='white', fontweight='bold', fontsize='large')
pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_SiO.pdf',bbox_inches='tight')
pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_SiO.png',bbox_inches='tight', dpi=200)

# %%
plot_maxpv(cube_27, 0.75)
plt.text(10, 30, 'SiO (5-4)', color='white', fontweight='bold', fontsize='large')
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2aec77ffc670>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: All-NaN slice encountered
#   out = function(self._get_filled_data(fill=fill,
# WARNING: WCSWarning: Slicing across a celestial axis results in an invalid WCS, so the celestial projection (TAN) is being removed.  The WCS indices being kept were [0 2]. [spectral_cube.wcs_utils]
# Text(10, 30, 'SiO (5-4)')

# %%
cube = cube_29
ww = wcs.WCS(cube.header)
pixelarea = ww.proj_plane_pixel_area().to(u.arcmin**2,equivalencies=u.dimensionless_angles())
path = Path([(2,cube.shape[1]/2.),(cube.shape[2]-2,cube.shape[1]/2.)], width = 2*u.arcmin / np.sqrt(pixelarea))
pvdiagram_29 = extract_pv_slice(cube=cube, path=path, spacing=1)

# %%
aspect = 0.37
plot_position_velocity(pvdiagram_29, aspect)
plt.text(10, 30, '$^{13}$CO (2-1)', color='white', fontweight='bold', fontsize='large')

pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_13CO.pdf',bbox_inches='tight')
pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_13CO.png',bbox_inches='tight', dpi=200)

# %%
plot_maxpv(cube_29, 0.37)
plt.text(10, 30, '$^{13}$CO (2-1)', color='white', fontweight='bold', fontsize='large')
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2aec77ffc670>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: All-NaN slice encountered
#   out = function(self._get_filled_data(fill=fill,
# WARNING: WCSWarning: Slicing across a celestial axis results in an invalid WCS, so the celestial projection (TAN) is being removed.  The WCS indices being kept were [0 2]. [spectral_cube.wcs_utils]
# Text(10, 30, '$^{13}$CO (2-1)')

# %%
cube = cube_31
ww = wcs.WCS(cube.header)
pixelarea = ww.proj_plane_pixel_area().to(u.arcmin**2,equivalencies=u.dimensionless_angles())
path = Path([(2,cube.shape[1]/2.),(cube.shape[2]-2,cube.shape[1]/2.)], width = 2*u.arcmin / np.sqrt(pixelarea))
pvdiagram_31 = extract_pv_slice(cube=cube, path=path, spacing=1)

# %%
aspect = 0.37
plot_position_velocity(pvdiagram_31, aspect)
plt.text(10, 30, 'C$^{18}$O (2-1)', color='white', fontweight='bold', fontsize='large')

pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_C18O.pdf',bbox_inches='tight')
pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_C18O.png',bbox_inches='tight', dpi=200)

# %%
plot_maxpv(cube_31, 0.37)
plt.text(10, 30, 'C$^{18}$O (2-1)', color='white', fontweight='bold', fontsize='large')
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2aec77ffc670>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# WARNING: WCSWarning: Slicing across a celestial axis results in an invalid WCS, so the celestial projection (TAN) is being removed.  The WCS indices being kept were [0 2]. [spectral_cube.wcs_utils]
# Text(10, 30, 'C$^{18}$O (2-1)')

# %%
#norm = simple_norm(pvdiagram.data, 'asinh')
#fig = pl.figure(figsize=(6,6))
#ax = pl.subplot(111, projection=wcs.WCS(pvdiagram.header))
##im = ax.imshow(pvdiagram.data, norm=norm, cmap='afmhot')
#im = ax.imshow(pvdiagram.data, norm=norm, cmap='inferno')
##im = ax.imshow(pvdiagram.data, norm=norm)
#ax0 = ax.coords[0]
#ax0.set_format_unit(u.arcmin)
#ax1 = ax.coords[1]
#ax1.set_format_unit(u.km/u.s)
#ax.set_ylabel("Velocity [km/s]")
#ax.set_xlabel("Offset [arcmin]")
#ax.set_aspect(0.6)

# %%
#plot_pv(cube_17, path, 0.2)
#plot_pv(kcube_13CO, path, 0.2)
#plot_pv(kcube_C18O, path, 0.2)
#plot_pv(kcube_CH3OH, path, 0.4)
#plot_pv(kcube_SiO, path, 0.4)
#plot_pv(kcube_H2CO_spw23, path, 0.4)
#plot_pv(kcube_H2CO_spw25, path, 0.4)

# %%
### Max instead of avg PV 
#plt.imshow(posv)

# %%
posv = cube_27.max(axis=1)#np.max(cube_27.unitless, axis=1)
aspect = 0.75

pl.figure(figsize=(6,6))
ww = wcs.WCS(posv.header)
ax = pl.subplot(111, projection=ww)
im = ax.imshow(posv.data)

ax0 = ax.coords[0]
ax0.set_format_unit(u.arcmin)
ax1 = ax.coords[1]
ax1.set_format_unit(u.km/u.s)
ax.set_ylabel("Velocity [km/s]")
ax.set_xlabel("Offset [arcmin]")
cb = pl.colorbar(mappable=im)
cb.set_label(cube.unit)
plt.text(10, 30, 'SiO (5-4)', color='white', fontweight='bold', fontsize='large')

ax.set_aspect(aspect)
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2b946e2d8ee0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: All-NaN slice encountered
#   out = function(self._get_filled_data(fill=fill,
# WARNING: WCSWarning: Slicing across a celestial axis results in an invalid WCS, so the celestial projection (TAN) is being removed.  The WCS indices being kept were [0 2]. [spectral_cube.wcs_utils]

# %%
def plot_pv(cube, path, aspect):
    plt.rcParams.update({'font.size': 18})

    pvdiagram = extract_pv_slice(cube=cube, path=path, spacing=1)
    
    pl.figure(figsize=(6,6))

    #ax = pl.subplot(111, projection=wcs.WCS(pvdiagram.header))
    #im = ax.imshow(pvdiagram.data)
    #cb = pl.colorbar(mappable=im)

    ww = wcs.WCS(pvdiagram.header)
    
    norm = simple_norm(pvdiagram.data, 'asinh')

    ax = pl.subplot(111, projection=ww)
    
    #im = ax.imshow(pvdiagram.data, norm=norm, cmap='afmhot')#, norm=LogNorm())
    im = ax.imshow(pvdiagram.data, norm=norm, cmap='inferno')#, norm=LogNorm())    
    
    cb = pl.colorbar(mappable=im)
    #cb.set_label("Brightness Temperature [K]")
    cb.set_label(cube.unit)
    #ax.set_aspect(aspect)

    ax0 = ax.coords[0]
    ax0.set_format_unit(u.arcmin)
    ax1 = ax.coords[1]
    ax1.set_format_unit(u.km/u.s)

    ax.set_ylabel("Velocity [km/s]")
    ax.set_xlabel("Offset [arcmin]")
    
    #ax.show()
    
    #pl.gca().invert_yaxis()
    
    #ax.set_title('PV Diagram of $^{12}$CO (2-1)')
    #ax.set_title('PV Diagram of $^{13}$CO (2-1)')
    #ax.set_title('PV Diagram of C$^{18}$O (2-1)')
    #ax.set_title('PV Diagram of CH$_3$OH')
    #ax.set_title('PV Diagram of SiO')
    #ax.set_title('PV Diagram of H2CO 3$_{2,1}$-2$_{2,0}$')
    #ax.set_title('PV Diagram of H2CO 3$_{0,3}$-2$_{0,2}$')
    
    #pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_afmhot_12CO.png')
    #pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_12CO.pdf')
    #pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_13CO.pdf')
    #pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_C18O.pdf')
    #pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_CH3OH.pdf')
    #pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_SiO.pdf')
    #pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_H2CO_spw23.pdf')
    #pl.savefig('/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_H2CO_spw25.pdf')

# %%
plot_pv(cube_17, path, 0.2)
#plot_pv(kcube_13CO, path, 0.2)
#plot_pv(kcube_C18O, path, 0.2)
#plot_pv(kcube_CH3OH, path, 0.4)
#plot_pv(kcube_SiO, path, 0.4)
#plot_pv(kcube_H2CO_spw23, path, 0.4)
#plot_pv(kcube_H2CO_spw25, path, 0.4)

# %%
#plot_pv(cube_12CO, path, 0.1)
#plot_pv(cube_13CO, path, 0.2)
#plot_pv(cube_C18O, path, 0.2)

#pvdiagram_CH3OH = extract_pv_slice(cube=cube_CH3OH, path=path, spacing=1)
#pvdiagram_SiO = extract_pv_slice(cube=cube_SiO, path=path, spacing=1)
#pvdiagram_H2CO_spw23 = extract_pv_slice(cube=cube_H2CO_spw23, path=path, spacing=1)
#pvdiagram_H2CO_spw25 = extract_pv_slice(cube=cube_H2CO_spw25, path=path, spacing=1)

#print("CH3OH")
#plot_pv(cube_CH3OH, path, 0.5)

#plot_pv(cube_SiO, path, 0.5)
#print('H2CO 3(21)-2(20)')
#plot_pv(cube_H2CO_spw23, path, 0.5)
#print('H2CO 3(0,3)-2(0,2)')
#plot_pv(cube_H2CO_spw25, path, 0.5)

# %%
cube_1 = cube_CH3OH.with_spectral_unit(u.km/u.s, velocity_convention=None, rest_value=218.44005 * u.GHz)
cube_2 = cube_CH3OH.with_spectral_unit(u.km/u.s, velocity_convention=None, rest_value=218.47563 * u.GHz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/local/60838376/ipykernel_4591/951092910.py in <module>
# ----> 1 cube_1 = cube_CH3OH.with_spectral_unit(u.km/u.s, velocity_convention=None, rest_value=218.44005 * u.GHz)
#       2 cube_2 = cube_CH3OH.with_spectral_unit(u.km/u.s, velocity_convention=None, rest_value=218.47563 * u.GHz)
#
# NameError: name 'cube_CH3OH' is not defined

# %%
plot_pv(cube_1, path, 0.5)
plot_pv(cube_2, path, 0.5)

# %%
print("SiO (5-4)")
plot_pv(cube_SiO, path, 0.5)

# %%
print('H2CO 3(21)-2(20)')
plot_pv(cube_H2CO_spw23, path, 0.5)

# %%
print('H2CO 3(0,3)-2(0,2)')
plot_pv(cube_H2CO_spw25, path, 0.5)

# %%
#from pvextractor.gui import PVSlicer
#from spectral_cube import SpectralCube
#cube = SpectralCube.read('/orange/adamginsburg/cmz/g5/G5/sum/spw17_12CO/g5.12CO.spw17.im', format='casa')
#pv = PVSlicer(cube)
#pv.show()

# %%
'''
pvdiagram_12CO.writeto("/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_12CO.fits", overwrite=True)
pvdiagram_13CO.writeto("/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_13CO.fits", overwrite=True)
pvdiagram_C18O.writeto("/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_C18O.fits", overwrite=True)

pvdiagram_CH3OH.writeto("/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_CH3OH.fits", overwrite=True)
pvdiagram_SiO.writeto("/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_SiO.fits", overwrite=True)
pvdiagram_H2CO_spw23.writeto("/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_H2CO_spw23.fits", overwrite=True)
pvdiagram_H2CO_spw25.writeto("/orange/adamginsburg/cmz/g5/code/plots/pvdiagram_H2CO_spw25.fits", overwrite=True)
'''

# %%
kcube_12CO = cube_12CO.to(u.K)
kcube_13CO = cube_13CO.to(u.K)
kcube_C18O = cube_C18O.to(u.K)
kcube_CH3OH = cube_CH3OH.to(u.K)
kcube_SiO = cube_SiO.to(u.K)
kcube_H2CO_spw23 = cube_H2CO_spw23.to(u.K)
kcube_H2CO_spw25 = cube_H2CO_spw25.to(u.K)

# %%
kpvdiagram_12CO = extract_pv_slice(cube=kcube_12CO, path=path, spacing=1)

kpvdiagram_13CO = extract_pv_slice(cube=kcube_13CO, path=path, spacing=1)
kpvdiagram_C18O = extract_pv_slice(cube=kcube_C18O, path=path, spacing=1)

kpvdiagram_CH3OH = extract_pv_slice(cube=kcube_CH3OH, path=path, spacing=1)
kpvdiagram_SiO = extract_pv_slice(cube=kcube_SiO, path=path, spacing=1)
kpvdiagram_H2CO_spw23 = extract_pv_slice(cube=kcube_H2CO_spw23, path=path, spacing=1)
kpvdiagram_H2CO_spw25 = extract_pv_slice(cube=kcube_H2CO_spw25, path=path, spacing=1)

# %%
#kpvdiagram_12CO.writeto("/orange/adamginsburg/cmz/g5/code/plots/kpvdiagram_12CO.fits", overwrite=True)
#kpvdiagram_13CO.writeto("/orange/adamginsburg/cmz/g5/code/plots/kpvdiagram_13CO.fits", overwrite=True)
#kpvdiagram_C18O.writeto("/orange/adamginsburg/cmz/g5/code/plots/kpvdiagram_C18O.fits", overwrite=True)

#kpvdiagram_CH3OH.writeto("/orange/adamginsburg/cmz/g5/code/plots/kpvdiagram_CH3OH.fits", overwrite=True)
#kpvdiagram_SiO.writeto("/orange/adamginsburg/cmz/g5/code/plots/kpvdiagram_SiO.fits", overwrite=True)
#kpvdiagram_H2CO_spw23.writeto("/orange/adamginsburg/cmz/g5/code/plots/kpvdiagram_H2CO_spw23.fits", overwrite=True)
#kpvdiagram_H2CO_spw25.writeto("/orange/adamginsburg/cmz/g5/code/plots/kpvdiagram_H2CO_spw25.fits", overwrite=True)

# %%
#cube1 = kcube_SiO / kcube_H2CO_spw25

# %%
ax = pl.subplot(111, projection=kcube_SiO.wcs.celestial)
ax.imshow(kcube_SiO[25].value)

#plot_pv(cube1, path, aspect=0.5)

# %%
ax = pl.subplot(111, projection=kcube_H2CO_spw25.wcs.celestial)
ax.imshow(kcube_H2CO_spw25[25].value)

# %%
#cube1 = kcube_SiO/kcube_H2CO_spw25

#mask_SiO = kcube_SiO > 0.02*u.K
#masked_kcube_H2CO_spw25 = kcube_H2CO_spw25.with_mask(mask_SiO, wcs_tolerance=1e-3)  

cube_1 = kcube_SiO
cube_2 = kcube_H2CO_spw25

# %%
new_mask1 = (cube_1 > 0.02*u.K)# & (cube2 < 0.02*u.K)  
new_mask2 = (cube_2 > 0.02*u.K)

# %%
cube1 = cube_1.with_mask(new_mask1)
cube2 = cube_2.with_mask(new_mask2)

# %%
plot_pv(cube1, path, 0.5)
plot_pv(cube2, path, 0.5)

# %%
pv_1 = extract_pv_slice(cube=cube1, path=path, spacing=1)
pv_2 = extract_pv_slice(cube=cube2, path=path, spacing=1)

# %%
pv_3 = pv_1.data/pv_2.data

# %%
#plt.imshow()
#
#plt.savefig('plots/ratio.pdf')
from mpl_toolkits.axes_grid1 import make_axes_locatable

pl.figure(figsize=(12,6))
ax = plt.subplot()
im = ax.imshow(pv_3.data)

plt.gca().invert_yaxis()
# create an axes on the right side of ax. The width of cax will be 5%
# of ax and the padding between cax and ax will be fixed at 0.05 inch.
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size = '10%', pad=0.05)

plt.colorbar(im, cax=cax)

plt.show()

# %%
'#help(ax1)
#ax1.get_axislabel()
#help(cube)
cube.spectral_axis
cube.with_spectral_unit(u.km / u.s, velocity_convention='radio')

# %%
cube2 = SpectralCube.read('http://www.astropy.org/astropy-data/l1448/l1448_13co.fits')

# %%
path = Path([(20,20), (40,40), (60,20)])

# %%
pl.imshow(cube2[25].value, origin='lower')

# %%
ax = pl.subplot(111, projection=cube2.wcs.celestial)
ax.imshow(cube2[25].value)
path.show_on_axis(ax, spacing=1, color='r')

# %%
pvdiagram = extract_pv_slice(cube=cube2, path=path, spacing=1)
pvdiagram

# %%
ax = pl.subplot(111, projection=wcs.WCS(pvdiagram.header))
im = ax.imshow(pvdiagram.data)
cb = pl.colorbar(mappable=im)
# we could specify the colorbar units like this:
# cb.set_label(cube.unit)
# but the 'BUNIT' keyword is not set for these data, so we don't know the unit.  We instead manually specify:
cb.set_label("Brightness Temperature [K]")

ww = wcs.WCS(pvdiagram.header)

ax = pl.subplot(111, projection=ww)
im = ax.imshow(pvdiagram.data)
cb = pl.colorbar(mappable=im)
cb.set_label("Brightness Temperature [K]")

ax0 = ax.coords[0]
ax0.set_format_unit(u.arcmin)
ax1 = ax.coords[1]
ax1.set_format_unit(u.km/u.s)

ax.set_ylabel("Velocity [km/s]")
ax.set_xlabel("Offset [arcmin]")

# %%
mx = cube2.max(axis=0).value

# %%
pl.figure(figsize=(12,6))
ax = pl.subplot(121, projection=cube.wcs.celestial)
ax.imshow(mx)
path.show_on_axis(ax, spacing=1, color='r')

ww = wcs.WCS(pvdiagram.header)

ax = pl.subplot(122, projection=ww)
im = ax.imshow(pvdiagram.data)

ax0 = ax.coords[0]
ax0.set_format_unit(u.arcmin)
ax1 = ax.coords[1]
ax1.set_format_unit(u.km/u.s)

ax.set_ylabel("Velocity [km/s]")
ax.set_xlabel("Offset [arcmin]")
