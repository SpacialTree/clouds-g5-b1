# %%
from astropy.visualization import quantity_support
from spectral_cube import SpectralCube
from astropy import units as u
import numpy as np
from astropy.io import fits
from astropy import wcs
import matplotlib.pyplot as plt
from reproject.mosaicking import find_optimal_celestial_wcs
from reproject import reproject_interp
from reproject.mosaicking import reproject_and_coadd

# %%
cube17a_name = '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.12CO.spw17.fits'
cube17a = SpectralCube.read(cube17a_name)
test = SpectralCube.read('/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/fitsImages/g5a.12CO.spw17.fits')


cube17b_name = '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/b/TP/2018.1.00862.S/baselineFixed/g5b.12CO.spw17.fits'
cube17b = SpectralCube.read(cube17b_name)
# Out:
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.io.core]

# %%
test_1 = SpectralCube.read('/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/spw21_CH3OH/g5a.CH3OH.spw21.im',format='casa_image')
# Out:
# /blue/adamginsburg/adamginsburg/repos/casa-formats-io/casa_formats_io/casa_dask.py:247: RuntimeWarning: divide by zero encountered in long_scalars
#   factors = [f for f in range(stacks[dim] + 1) if stacks[dim] % f == 0]
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.io.core]

# %%
test_1.moment0().quicklook()
#test_1.header
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/local/40863432/ipykernel_50496/3341365047.py in <module>
# ----> 1 test_1.moment0().quicklook()
#       2 #test_1.header
#
# NameError: name 'test_1' is not defined

# %%
a_fixednames = ['/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.12CO.spw17.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.Ha.spw19.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.CH3OH.spw21.fits',
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.H2CO.spw23.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.H2CO.spw25.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.SiO.spw27.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.13CO.spw29.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.C18O.spw31.fits' 
               ]
cube17 = SpectralCube.read(a_fixednames[0]).with_spectral_unit(u.GHz, velocity_convention='radio')
cube21 = SpectralCube.read(a_fixednames[2]).with_spectral_unit(u.GHz, velocity_convention='radio')
cube23 = SpectralCube.read(a_fixednames[3]).with_spectral_unit(u.GHz, velocity_convention='radio')
cube25 = SpectralCube.read(a_fixednames[4]).with_spectral_unit(u.GHz, velocity_convention='radio')
cube27 = SpectralCube.read(a_fixednames[5]).with_spectral_unit(u.GHz, velocity_convention='radio')
cube29 = SpectralCube.read(a_fixednames[6]).with_spectral_unit(u.GHz, velocity_convention='radio')
cube31 = SpectralCube.read(a_fixednames[7]).with_spectral_unit(u.GHz, velocity_convention='radio')

# %%
old_cube27 = SpectralCube.read('/orange/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/spw27_SiO/g5a.SiO.spw27.im', format='casa_image').to(u.K)
# Out:
# /blue/adamginsburg/adamginsburg/repos/casa-formats-io/casa_formats_io/casa_dask.py:247: RuntimeWarning: divide by zero encountered in long_scalars
#   factors = [f for f in range(stacks[dim] + 1) if stacks[dim] % f == 0]
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.io.core]
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.to at 0x2b7754425f70>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]

# %%
#wcs_out, shape_out = find_optimal_celestial_wcs([cube17b.moment(order=0).hdu, cube17a.moment(order=0).hdu], frame='fk5', auto_rotate=True)
#wcs_out.to_header()
# Out:
# WCSAXES =                    2 / Number of coordinate axes
# CRPIX1  =      129.89497533266 / Pixel coordinate of reference point
# CRPIX2  =      202.38608434709 / Pixel coordinate of reference point
# PC1_1   =     0.99999998309583 / Coordinate transformation matrix element
# PC1_2   =  0.00018387042311696 / Coordinate transformation matrix element
# PC2_1   = -0.00018387042311696 / Coordinate transformation matrix element
# PC2_2   =     0.99999998309583 / Coordinate transformation matrix element
# CDELT1  =  -0.0007795761902778 / [deg] Coordinate increment at reference point
# CDELT2  =   0.0007795761902778 / [deg] Coordinate increment at reference point
# CUNIT1  = 'deg'                / Units of coordinate increment and value
# CUNIT2  = 'deg'                / Units of coordinate increment and value
# CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
# CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
# ...

# %%
#array, footprint = reproject_and_coadd([cube17b.moment(order=0).hdu, cube17a.moment(order=0).hdu],
#                                       wcs_out, shape_out=shape_out,
#                                       reproject_function=reproject_interp)

# %%
#ax = plt.subplot(111, projection=wcs_out)
#plt.imshow(array)

# %%
#array1, footprint1 = reproject_interp(cube17b.moment(order=0).hdu, wcs_out, shape_out)

# %%
#ax = plt.subplot(111, projection=cube17b.wcs.celestial)
#cube17b.spectral_slab(0*u.km / u.second, 200*u.km/u.second).moment0().quicklook()
#ax2 = plt.subplot(111, projection=cube17a.wcs.celestial)
#cube17a.spectral_slab(0*u.km / u.second, 200*u.km/u.second).moment0().quicklook()

# %%
#sub_cube = cube17b[:, 80:120, 120:180]
#sub_cube = cube17b[:, 50:120, :60]
sub_cube = cube17b[:, 98:99, 50:51]
ax = plt.subplot(111, projection=sub_cube.wcs.celestial)
sub_cube.spectral_slab(0*u.km / u.second, 200*u.km/u.second).moment0().quicklook()
cb = plt.colorbar()
cb.set_label(sub_cube.unit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/local/41104043/ipykernel_66333/1000573042.py in <module>
#       1 #sub_cube = cube17b[:, 80:120, 120:180]
#       2 #sub_cube = cube17b[:, 50:120, :60]
# ----> 3 sub_cube = cube17b[:, 98:99, 50:51]
#       4 ax = plt.subplot(111, projection=sub_cube.wcs.celestial)
#       5 sub_cube.spectral_slab(0*u.km / u.second, 200*u.km/u.second).moment0().quicklook()
#
# NameError: name 'cube17b' is not defined

# %%
avspec17b = sub_cube.mean(axis=(1,2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/local/41104043/ipykernel_66333/3759395034.py in <module>
# ----> 1 avspec17b = sub_cube.mean(axis=(1,2))
#
# NameError: name 'sub_cube' is not defined

# %%
avspec17b.quicklook()
plt.ylim(top=9,bottom=-2)
# Out:
# (-2.0, 9.0)

# %%
region_str = "circle[[0deg, 0deg], 0.1deg], coord=galactic, range=[150km/s, 300km/s]"  
sub_cube = cube.subcube_from_crtfregion(region_str)

# %%
cube17.moment0().quicklook()
# Out:
# INFO: Auto-setting vmin to  1.118e-01 [aplpy.core]
# INFO: Auto-setting vmax to  6.047e-01 [aplpy.core]

# %%
sub_cube17 = cube17[:, 100:200, 50:125]
sub_cube17.moment0().quicklook()
# Out:
# INFO: Auto-setting vmin to  1.237e-01 [aplpy.core]
# INFO: Auto-setting vmax to  6.090e-01 [aplpy.core]

# %%
avspec17 = sub_cube17.mean(axis=(1,2))
avspec17.quicklook()
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x2ae9e16cf160>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]

# %%
sub_cube17 = cube17[:, 100:200, 50:125]
sub_cube21 = cube21[:, 100:200, 50:125]
sub_cube23 = cube23[:, 100:200, 50:125]
sub_cube25 = cube25[:, 100:200, 50:125]
sub_cube27 = cube27[:, 100:200, 50:125]
sub_cube29 = cube29[:, 100:200, 50:125]
sub_cube31 = cube31[:, 100:200, 50:125]

# %%
sub_old_cube27 = old_cube27[:, :, :].with_spectral_unit(u.GHz, velocity_convention='radio')
sub_old_cube27.moment0().quicklook()

# %%
avspec_old27 = sub_old_cube27.mean(axis=(1,2))
sub_cube27 = cube27[:, :, :]
avspec27 = sub_cube27.mean(axis=(1,2))
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x2b7754420a60>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]

# %%
avspec17 = sub_cube17.mean(axis=(1,2))
avspec21 = sub_cube21.mean(axis=(1,2))
avspec23 = sub_cube23.mean(axis=(1,2))
avspec25 = sub_cube25.mean(axis=(1,2))
avspec27 = sub_cube27.mean(axis=(1,2))
avspec29 = sub_cube29.mean(axis=(1,2))
avspec31 = sub_cube31.mean(axis=(1,2))
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x2ae9e16cf160>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x2ae9e16cf160>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x2ae9e16cf160>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x2ae9e16cf160>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x2ae9e16cf160>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# ...

# %%
plt.figure(figsize=(18,6))
#avspec17.quicklook(label='$^{12}$CO (2-1)')
#avspec21.quicklook(label='CH$_3$OH (4$_{2,2}$-3$_{1,2}$)')
#avspec23.quicklook(label='H$_2$CO (3$_{2,1}$-2$_{2,0}$)')
#avspec25.quicklook(label='H$_2$CO (3$_{0,3}$-2$_{0,2}$)')
#avspec27.quicklook(label='SiO (5-4)')
#avspec29.quicklook(label='$^{13}$CO (2-1)')
avspec31.quicklook(label='C$^{18}$O (2-1)')

#avspec_old27.quicklook(label='SiO (5-4)')

#plt.xscale('log')
# 'linear', 'log', 'symlog', 'logit', 'function', 'functionlog'
#plt.yscale('log')
plt.ylim(bottom=-0.01,top=0.03)
plt.legend(loc='upper left')
plt.axhline(0,color='red')
#plt.axhline(0.006,color='red') # spw21
#plt.axhline(0.0085,color='red') # spw23
#plt.axhline(0.011,color='red') # spw25
#plt.axhline(0.0124,color='red') # spw27
#plt.axhline(0.0215,color='red') # spw31

#plt.ylim(top=0.1,bottom=-0.1)
#plt.savefig('plots/fullspectrum.pdf')
#plt.savefig('plots/adjustedspectrum.pdf')

# %%
plt.plot(avspec_old27,label='Old SiO')
plt.plot(avspec27,label='Baseline Fixed SiO')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/local/41104043/ipykernel_66333/3148181106.py in <module>
# ----> 1 plt.plot(avspec_old27,label='Old SiO')
#       2 plt.plot(avspec27,label='Baseline Fixed SiO')
#       3 plt.legend()
#
# NameError: name 'avspec_old27' is not defined

# %%
avspec27[:150].quicklook(label='SiO (5-4)')

# %%
avspec27 = settled_27.mean(axis=(1,2))
avspec27.quicklook(label='SiO (5-4)')
plt.ylim(bottom=0,top=0.0125)
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x2ae9e16cf160>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# (0.0, 0.0125)

# %%
np.mean(avspec27[:150])
# Out:
# <Quantity 0.01242598 K>

# %%
#settled_27.write('/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.SiO.spw27.fits')#,overwrite=True)

# %%
avspec_old27
# Out:
# <OneDSpectrum [-1.04093569e-03,-5.41371496e-04,-5.26398493e-04,
#                 2.87084213e-04,-4.48081924e-04,-9.44843014e-04,
#                 2.98354869e-04,-7.47825982e-04,-2.82200963e-04,
#                -5.65849178e-04,-1.37768968e-03,-9.98030150e-04,
#                -1.19020341e-03,-7.00222891e-04, 9.59402257e-05,
#                 3.79396919e-04, 3.79171215e-05, 4.10267330e-04,
#                -1.89042183e-04,-7.97440395e-04,-4.71563063e-05,
#                -9.33213071e-05,-6.87870653e-05, 4.38738295e-05,
#                -5.32098161e-04,-2.44858508e-04,-4.97774546e-04,
#                -5.27885953e-04,-1.02629612e-03,-9.94300251e-04,
#                 4.11415523e-04, 7.29947644e-04,-1.55608255e-04,
#                 7.08962232e-04, 4.59873916e-04,-2.14640196e-05,
#                -7.66912118e-04,-4.03835365e-05, 1.35426098e-04,
#                 7.01357177e-04, 3.33588496e-04, 4.87148642e-04,
#                -7.21772981e-04, 1.11248834e-04,-3.72191742e-04,
# ...

# %%
#plt.axhline(0.006,color='red') # spw21
#plt.axhline(0.0085,color='red') # spw23
#plt.axhline(0.011,color='red') # spw25
#plt.axhline(0.0124,color='red') # spw27
#plt.axhline(0.0215,color='red') # spw31

# %%
adj21 = cube21 - 0.006 * u.K
adj23 = cube23 - 0.0085 * u.K
adj25 = cube25 - 0.011 * u.K
adj27 = cube27 - 0.0124 * u.K
adj31 = cube31 - 0.0215 * u.K
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube._apply_everywhere at 0x2ae9e16d01f0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube._apply_everywhere at 0x2ae9e16d01f0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube._apply_everywhere at 0x2ae9e16d01f0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube._apply_everywhere at 0x2ae9e16d01f0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# ...

# %%
adj21.write('/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.CH3OH.spw21.fits'#,overwrite=True)
adj23.write('/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.H2CO.spw23.fits'#,overwrite=True)
adj25.write('/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.H2CO.spw25.fits'#,overwrite=True)
adj27.write('/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.SiO.spw27.fits'#,overwrite=True)
adj31.write('/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/baselineFixed/g5a.C18O.spw31.fits'#,overwrite=True)
