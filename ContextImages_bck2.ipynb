# %%
from astroquery import sha
from astropy import coordinates as coord
from astropy import units as u
import matplotlib.pyplot as plt
from spectral_cube import SpectralCube
from astropy.visualization import quantity_support
from astropy.wcs import WCS
import numpy as np
from astropy.visualization import simple_norm
from astropy.nddata import Cutout2D
from reproject import reproject_interp
from matplotlib.patches import Circle
# Out:
# /scratch/local/25260084/ipykernel_15927/4040820004.py:1: DeprecationWarning: the ``sha`` module has been moved to astroquery.ipac.irsa.sha, please update your imports.
#   from astroquery import sha
# /blue/adamginsburg/adamginsburg/repos/astroquery/astroquery/ipac/irsa/sha/__init__.py:14: UserWarning: Experimental: SHA has not yet been refactored to have its API match the rest of astroquery.
#   warnings.warn("Experimental: SHA has not yet been refactored to have its "

# %%
import requests
import re
import numpy as np
from astropy import table
import io
import time
from astropy import units as u
import radio_beam
import regions
from astropy.io import fits
from astropy.visualization import simple_norm
from astropy import stats, convolution, wcs, coordinates
from spectral_cube import SpectralCube
import pylab as pl
import spectral_cube
from spectral_cube import Projection,SpectralCube
import reproject

#from spectralindex import prefixes

import warnings
warnings.filterwarnings('ignore', category=spectral_cube.utils.StokesWarning)
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=pl.matplotlib.cbook.MatplotlibDeprecationWarning)
np.seterr('ignore')

glimpses=g_subsets=['glimpsei_0_6', 'glimpseii_0_6', 'glimpse3d_0_6',
                    'glimpse360_0_6', 'glimpse_cygx_0_6',
                    'glimpse_deepglimpse_0_6', 'glimpse_smog_0_6',
                    'glimpse_velacar_0_6', 'mipsgal_images']

# %% [markdown]
# ## Spitzer

# %%
def get_spitzer_data(crd, size):
    files = {}
    for spitzertbl in glimpses:
        if 'glimpse' in spitzertbl:
            url = f"https://irsa.ipac.caltech.edu/IBE?table=spitzer.{spitzertbl}&POS={crd.ra.deg},{crd.dec.deg}&ct=csv&mcen&where=fname+like+'%.fits'"
        else:
            url = f"https://irsa.ipac.caltech.edu/IBE?table=spitzer.{spitzertbl}&POS={crd.ra.deg},{crd.dec.deg}&ct=csv&where=fname+like+'%.fits'"
        response = requests.get(url)
        response.raise_for_status()
        tbl = table.Table.read(io.BytesIO(response.content), format='ascii.csv')

        if (len(tbl) >= 4) and 'I1' not in files:
            fnames = tbl['fname']

            for fname in fnames:
                irsa_url = f"https://irsa.ipac.caltech.edu/ibe/data/spitzer/{spitzertbl}/{fname}?center={crd.ra.deg},{crd.dec.deg}&size={size.to(u.arcmin).value}arcmin"

                key = re.search("I[1-4]", fname).group()

                fh = fits.open(irsa_url)
                files[key] = fh
        elif 'mipsgal' in spitzertbl:
            fnames = tbl['fname']
            for fname in fnames:
                irsa_url = f"https://irsa.ipac.caltech.edu/ibe/data/spitzer/{spitzertbl}/{fname}?center={crd.ra.deg},{crd.dec.deg}&size={size.to(u.arcmin).value}arcmin"
                if 'mosaics24' in irsa_url and 'covg' not in irsa_url and 'mask' not in irsa_url and 'std' not in irsa_url:
                    fh = fits.open(irsa_url)
                    files['MG'] = fh
    return files

# %%
def show_contours_on_spitzer(fieldid, image, spitzerpath='spitzer_datapath',
                             spitzer_display_args=dict(stretch='log', min_percent=1, max_percent=99.99, clip=True),
                             mips=False,
                             figsize=(10,10),
                             color='orange',
                             zoom=None,
                             line=None,
                             contour_levels=None):
    """
    image should be Projection-like: should have .wcs.celestial
    """


    spitzfn = f'{spitzerpath}/{fieldid}_spitzer_images.fits'
    if mips:
        spitzfn = spitzfn.replace("spitzer", "mips")
    spitz = fits.open(spitzfn)[0]

    ww = wcs.WCS(spitz.header)

    fig = pl.figure(1, figsize=figsize)
    fig.clf()
    ax = fig.add_subplot(projection=ww.celestial)

    spitz_data = np.array([simple_norm(x, **spitzer_display_args)(x) for x in spitz.data])

    ax.imshow(spitz_data.T.swapaxes(0,1))

    lims = ax.axis()


    if zoom:
        xdiff = lims[1] - lims[0]
        ydiff = lims[3] - lims[2]
        lims = (lims[0] + xdiff/zoom/2,
                lims[1] - xdiff/zoom/2,
                lims[2] + ydiff/zoom/2,
                lims[3] - ydiff/zoom/2)
    else:
        zoom = 1

    ax.contour(image, transform=ax.get_transform(image.wcs.celestial), levels=contour_levels, colors=[color], linewidths=[0.5])

    ax.axis(lims)
    ax.set_xlabel('Galactic Longitude')
    ax.set_ylabel('Galactic Latitude')

    txtpos = [0.97, 0.97]
    # xx,yy = ax.transData.inverted().transform(ax.transAxes.transform(txtpos))
    # arr = ax.images[0].get_array()
    # bgcolor = arr[int(xx)-2:int(xx)+2, int(yy)-2:int(yy)+2, :].mean(axis=(0,1))

    # #from matplotlib.colors import rgb_to_hsv, hsv_to_rgb

    # #def complementary(r, g, b):
    # #    """returns RGB components of complementary color"""
    # #    hsv = rgb_to_hsv((r, g, b))
    # #    # force saturation to 1
    # #    return hsv_to_rgb(((hsv[0] + 0.5) % 1, 1, 1))

    # if np.any(bgcolor.mask) or bgcolor.mean() < 0.5:
    #     txcolor = 'white'
    # else:
    #     txcolor = 'black' #complementary(*bgcolor)
    txcolor = 'white'

    text = fieldid
    if line:
        text = f'{text}\n{line}'

    txt = ax.text(*txtpos, text, horizontalalignment='right',
                  #fontweight='bold',
                  color=txcolor,
                  fontsize=22,
                  verticalalignment='top', transform=ax.transAxes)

    #pl.figure(2).gca().imshow(image_b6.mask.include()[0])
    return fig

# %%
loc = '/orange/adamginsburg/cmz/g5/G5/sum/spw17_12CO/g5.mom0.smK.tot.12CO.spw17.im/'
# g5.12CO.spw17.im/
mom0_12CO = SpectralCube.read(loc, format='casa')#.with_spectral_unit(u.km / u.s, velocity_convention='radio')
cube = mom0_12CO

# %%
size = np.abs(np.max(cube.shape[1:] * cube.wcs.pixel_scale_matrix.diagonal()[:2])*u.deg)*1.5
center = coordinates.SkyCoord(*cube[0].world[int(cube.shape[1]/2), int(cube.shape[2]/2)][::-1],
                              frame=wcs.utils.wcs_to_celestial_frame(cube.wcs))
center = center.transform_to('fk5')

# %%
spitzer_data = get_spitzer_data(center, size)
assert 'I1' in spitzer_data
assert 'MG' in spitzer_data

# %%
spitzer_cube = np.array([spitzer_data['I4'][0].data, spitzer_data['I2'][0].data, spitzer_data['I1'][0].data, ])
#fits.PrimaryHDU(data=spitzer_cube, header=spitzer_data['I1'][0].header).writeto(spitzer_cubename, overwrite=True)

mipsdata,_ = reproject.reproject_interp(spitzer_data['MG'][0], spitzer_data['I1'][0].header)
mipsdata[np.isnan(mipsdata)] = np.nanmax(mipsdata)
mips_cube = np.array([mipsdata, spitzer_data['I4'][0].data, spitzer_data['I1'][0].data, ])
#fits.PrimaryHDU(data=mips_cube, header=spitzer_data['I1'][0].header).writeto(spitzer_cubename.replace("spitzer", "mips"), overwrite=True)

# %%
spitzer_data
# Out:
# {'I2': [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x2b531bc68100>],
#  'I3': [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x2b531bf41b80>],
#  'I1': [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x2b531bc686d0>],
#  'I4': [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x2b531bf65dc0>],
#  'MG': [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x2b531bf0d3d0>]}

# %%
'''def plot_spitz(spitz, image, contour_levels):
    spitz = spitz[0]
    ww = wcs.WCS(spitz.header)
    fig = pl.figure(1, figsize=(8,8))
    #fig.ckf()
    ax = fig.add_subplot(projection=ww.celestial)
    spitzer_display_args=dict(stretch='log', min_percent=1, max_percent=99.99, clip=True)
    spitz_data = np.array([simple_norm(x, **spitzer_display_args)(x) for x in spitz.data])
    ax.imshow(spitz_data.T.swapaxes(0,1))
    lims = ax.axis()
    ax.contour(image, transform=ax.get_transform(image.wcs.celestial), levels=contour_levels, colors='white', linewidths=[1.5])
    ax.coords['glon'].set_axislabel('Galactic Longitude')
    ax.coords['glat'].set_axislabel('Galactic Latitude')

#for im in spitzer_data.items():
#    plot_spitz(im)
    #spitz = fits.open(im[1])[0]'''
# Out:
# "def plot_spitz(spitz, image, contour_levels):\n    spitz = spitz[0]\n    ww = wcs.WCS(spitz.header)\n    fig = pl.figure(1, figsize=(8,8))\n    #fig.ckf()\n    ax = fig.add_subplot(projection=ww.celestial)\n    spitzer_display_args=dict(stretch='log', min_percent=1, max_percent=99.99, clip=True)\n    spitz_data = np.array([simple_norm(x, **spitzer_display_args)(x) for x in spitz.data])\n    ax.imshow(spitz_data.T.swapaxes(0,1))\n    lims = ax.axis()\n    ax.contour(image, transform=ax.get_transform(image.wcs.celestial), levels=contour_levels, colors='white', linewidths=[1.5])\n    ax.coords['glon'].set_axislabel('Galactic Longitude')\n    ax.coords['glat'].set_axislabel('Galactic Latitude')\n\n#for im in spitzer_data.items():\n#    plot_spitz(im)\n    #spitz = fits.open(im[1])[0]"

# %%
def plot_spitz(spitz, image, contour_levels):
    #spitz = spitz[0]
    ww = wcs.WCS(spitz.header)
    #print(ww.proj_plane_pixel_scales)
    fig = pl.figure(1, figsize=(8,8))
    #fig.ckf()
    ax = fig.add_subplot(projection=ww.celestial)
    spitzer_display_args=dict(stretch='linear', min_percent=7, max_percent=90., clip=True)
    #spitz_data = simple_norm(spitz.data, **spitzer_display_args)(spitz.data)
    spitz_data = np.array([simple_norm(x, **spitzer_display_args)(x) for x in spitz.data])
    ax.imshow(spitz_data.T.swapaxes(0,1))
    lims = ax.axis()
    ax.contour(image, transform=ax.get_transform(image.wcs.celestial), levels=contour_levels, colors='white', linewidths=[1.5])
    ax.coords['glon'].set_axislabel('Galactic Longitude')
    ax.coords['glat'].set_axislabel('Galactic Latitude')
    return ax
    # (11.2681, -61.2931) (304.29243304, -55.81833393)
    
    #s = np.pi * (u.pixel_scale(u.pixel/15*u.arcsec))**2
    #s = np.pi*(15*u.arcsec)**2
    #print(WCS.proj_plane_pixel_scales(ww))
    #s = s.to(u.arcmin**2)
    #ax.scatter(304.29243304, -55.81833393, transform=ax.get_transform(image.wcs.celestial), s=s,
    #       edgecolor='cyan')#, facecolor='none')
    #print(s)
    # 15*u.arcsec
    #c = Circle((304.29243304, -55.81833393), 15*u.arcsec, edgecolor='yellow', facecolor='none',
     #      transform=ax.get_transform(image.wcs.celestial))
    #ax.add_patch(c)

# %%
'''loc1 = '/orange/adamginsburg/cmz/g5/G5/sum/spw17_12CO/g5.mom0.smK.tot.12CO.spw17.im/'
# g5.12CO.spw17.im/ # g5.mom0.smK.tot.12CO.spw17.im/
cube = SpectralCube.read(loc1, format='casa_image')
#pbv,_ = reproject.reproject_interp(pb[10].hdu, fh[0].header)

                # 10th channel is arbitrary but avoids edge channel
#data = fh[0].data * pbv
data = cube[0].hdu.data


m0 = Projection(data, wcs=wcs.WCS(cube[0].hdu.header))


std = stats.mad_std(data, ignore_nan=True)
levels = np.array([3, 5, 10, 20, 30])*std

m0 = Projection(data, wcs=wcs.WCS(cube[0].hdu.header))
contour_levels = np.logspace(0, 5, num=25)
    
plot_spitz(spitzer_data['I4'], m0, contour_levels)

#cube[0].hdu.data'''
# Out:
# "loc1 = '/orange/adamginsburg/cmz/g5/G5/sum/spw17_12CO/g5.mom0.smK.tot.12CO.spw17.im/'\n# g5.12CO.spw17.im/ # g5.mom0.smK.tot.12CO.spw17.im/\ncube = SpectralCube.read(loc1, format='casa_image')\n#pbv,_ = reproject.reproject_interp(pb[10].hdu, fh[0].header)\n\n                # 10th channel is arbitrary but avoids edge channel\n#data = fh[0].data * pbv\ndata = cube[0].hdu.data\n\n\nm0 = Projection(data, wcs=wcs.WCS(cube[0].hdu.header))\n\n\nstd = stats.mad_std(data, ignore_nan=True)\nlevels = np.array([3, 5, 10, 20, 30])*std\n\nm0 = Projection(data, wcs=wcs.WCS(cube[0].hdu.header))\ncontour_levels = np.logspace(0, 5, num=25)\n    \nplot_spitz(spitzer_data['I4'], m0, contour_levels)\n\n#cube[0].hdu.data"

# %%
import regions
from astropy.coordinates import SkyCoord

# %%
SkyCoord(5.392*u.deg, -0.3313*u.deg, frame='galactic')
# Out:
# <SkyCoord (Galactic): (l, b) in deg
#     (5.392, -0.3313)>

# %%
loc1 = '/orange/adamginsburg/cmz/g5/G5/sum/spw17_12CO/g5.mom0.smK.tot.12CO.spw17.im/'
# g5.12CO.spw17.im/ # g5.mom0.smK.tot.12CO.spw17.im/
cube = SpectralCube.read(loc1, format='casa_image')
#pbv,_ = reproject.reproject_interp(pb[10].hdu, fh[0].header)

                # 10th channel is arbitrary but avoids edge channel
#data = fh[0].data * pbv
data = cube[0].hdu.data

ww=wcs.WCS(cube[0].hdu.header)
m0 = Projection(data, wcs=ww)


std = stats.mad_std(data, ignore_nan=True)
levels = np.array([3, 5, 10, 20, 30])*std

m0 = Projection(data, wcs=wcs.WCS(cube[0].hdu.header))
contour_levels = np.logspace(0, 5, num=25)

spitz = fits.PrimaryHDU(data=[spitzer_data[filtername][0].data for filtername in ['I4','I2','I1']], header=spitzer_data['I4'][0].header)

ax = plot_spitz(spitz, m0, contour_levels)

reg = regions.RectangleSkyRegion(center=SkyCoord(5.378*u.deg, -0.408*u.deg, frame='galactic'), width=720*u.arcsec, height=150*u.arcsec, angle=0*u.deg)
preg = reg.to_pixel(wcs.WCS(spitz.header).celestial)
preg.plot(edgecolor='yellow')


#               edgecolor='green', facecolor='none',
#               transform=ax.get_transform('galactic'))

#r = Quadrangle((5.392, -0.3313)*u.deg, 720*u.arcsec, 150*u.arcsec,
#               edgecolor='green', facecolor='none',
#               transform=ax.get_transform('galactic'))
#ax.add_patch(r)

#a = ICRS(Angle('00:21:38.6451 degrees'),Angle('-00:25:26.057 degrees'))

#ax.scatter(a[0],a[1], transform=ax.get_transform('icrs'), s=300,
 #          edgecolor='white', facecolor='purple')
#cor = SkyCoord('17:59:12', '-24:27:50', frame='icrs')
# Out:
# <WCSAxesSubplot:xlabel='Galactic Longitude', ylabel='Galactic Latitude'>

# %%
preg.plot?
# Out:
# Signature: preg.plot(origin=(0, 0), ax=None, **kwargs)
# Docstring:
# Plot the region on a matplotlib `~matplotlib.axes.Axes`
# instance.
#
# Parameters
# ----------
# origin : array_like, optional
#     The ``(x, y)`` pixel position of the origin of the displayed
#     image.
#
# ax : `~matplotlib.axes.Axes` or `None`, optional
#     The matplotlib axes on which to plot.  If `None`, then the
#     current `~matplotlib.axes.Axes` instance is used.
#
# **kwargs : dict
#     Any keyword arguments accepted by
#     `~matplotlib.patches.Patch`.
#
# Returns
# -------
# ax : `~matplotlib.axes.Axes`
#     The axes on which the patch was added.
# File:      /blue/adamginsburg/adamginsburg/repos/regions/regions/core/core.py
# Type:      method

# %%
from astropy import units as u
from astropy.visualization.wcsaxes import Quadrangle
from astropy.coordinates import Angle
from astropy.coordinates import ICRS
from astropy.coordinates import SkyCoord

# %%
jsky = 'ALMA22/jsky13241953264208787586.fits'
hdul_t = fits.open(jsky)
im = hdul_t[0]
ww = wcs.WCS(im.header)
fig = pl.figure(1, figsize=(8,8))
ax = fig.add_subplot(projection=ww.celestial)
ax.imshow(im.data.T.swapaxes(0,1))
ax.contour(m0, transform=ax.get_transform(m0.wcs.celestial), levels=contour_levels, colors='white', linewidths=[1.5])

# %%
#cube[0].hdu.data
spitzer_data_2 = spitzer_data.copy()
spitzer_data_2['MG'] = [fits.PrimaryHDU(data=mipsdata, header=spitzer_data['I1'][0].header)]

spitz = fits.PrimaryHDU(data=[spitzer_data_2[filtername][0].data for filtername in ['MG','I4','I2']], header=spitzer_data['I4'][0].header)

plot_spitz(spitz, m0, contour_levels)
#plt.savefig('./plots/spitzer_2.pdf')
# Out:
# <WCSAxesSubplot:xlabel='Galactic Longitude', ylabel='Galactic Latitude'>

# %%
##### SOFIA
s_url1 = 'https://irsa.ipac.caltech.edu/data/SOFIA/GREAT/OC1C/20130724_F120/raw/r2/data/si/GREAT1_1_03/008657_003_GREAT_SAFFTS1.fits' 
s_url2 = 'https://irsa.ipac.caltech.edu/data/SOFIA/GREAT/OC1C/20130724_F120/raw/r2/data/si/GREAT1_1_03/008657_003_GREAT_CPBE1.fits'
s_url3 = 'https://irsa.ipac.caltech.edu/data/SOFIA/GREAT/OC1C/20130724_F120/raw/r2/data/si/GREAT1_1_03/008657_003_GREAT_SXFFTS1.fits'

s_fits1 = fits.open(s_url1)
s_fits2 = fits.open(s_url2)
s_fits3 = fits.open(s_url3)

shead=s_fits2[0].header

# %%
c = coord.SkyCoord(ra=shead['OBSRA']*u.deg, dec=shead['OBSDEC']*u.deg, equinox=shead['TELEQUI'])

# %%
c.galactic
# Out:
# <SkyCoord (Galactic): (l, b) in deg
#     (304.29243304, -55.81833393)>

# %%
s_fits1[0].header
# Out:
# SIMPLE  =                    T / Written by IDL:  Tue Sep 24 15:03:04 2013
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    4 / number of data axes
# NAXIS1  =                 8192 / length of data axis 1
# NAXIS2  =                    1 / length of data axis 2
# NAXIS3  =                    1 / length of data axis 3
# NAXIS4  =                    1 / length of data axis 4
# EXTEND  =                    T / FITS dataset may contain extensions
# DATASRC = 'ASTRO   '           / Data Source
# OBSTYPE = 'OBJECT  '           / Observation type
# SRCTYPE = 'UNKNOWN '           / Source type
# KWDICT  = 'DCS_ICD_revE '      /SOFIA Keyword dictionary version,
# OBS_ID  = '2013-07-24_GR_F120_GREAT_SAFFTS1_008657_003' / SOFIA Observation Iden
# OBJECT  = 'NGC3603 '           / SOURCE NAME
# AOT_ID  = 'UNKNOWN '           / Astronomical Observation Template Identifier
# AOR_ID  = '83_0004_30'         / Astronomical Observation Request Identifier
# PROCSTAT= 'LEVEL_1 '           / Processing status
# HEADSTAT= 'MODIFIED'           / Header status
# PIPELINE= 'UNKNOWN '           /
# PIPEVERS= 'UNKNOWN '           /
# PLANID  = '83_0004 '           / OBSERVING PLAN ID
# DEPLOY  = 'DAOF    '           / Site deployment
# MISSN-ID= '2013-07-24_GR_F120' / Mission ID
# FLIGHTLG=                    7 / Flight leg
# ORIGIN  = 'USRA GREAT - MPIfR/KOSMA' / Origin of FITS file.
# OBSERVER= 'Robert  '           / OBSERVER
# CREATOR = 'level1_reconstruct.pro (v1.1)' /CREATOR OF FITS FILE
# OPERATOR= 'Alan    '           / Telescope operator
# FILENAME= '008657_003_GREAT_SAFFTS1.fits' /Name of host file
# DATE-OBS= '2013-07-24T09:58:45' / UTC Date of exposure start
# UTCSTART= '09:58:45'           / UTC of exposure start
# UTCEND  = '09:58:55'           / UTC of exposure end
# WVZ_STA =               94.965 / Water vapor, zenith [microns], start of obs
# WVZ_END =               94.965 / Water vapor, zenithn [microns], end of obs
# TEMP_OUT=                211.4 / SKY TEMPERATURE [K]
# TEMPPRI1=               -36.35 / Temperature of primary mirror, 1 [C]
# TEMPPRI2=               -36.15 / Temperature of primary mirror, 2 [C]
# TEMPPRI3=               -35.05 / Temperature of primary mirror, 3 [C]
# TEMPSEC1=               -35.75 / Temperature of secondary mirror, 1 [C]
# ALTI_STA=               41013. / Aircraft pressure altitude, start of obs [ft]
# ALTI_END=               41006. / Aircraft pressure altitude, end of obs [ft]
# AIRSPEED=              483.125 / True aircraft airspeed [knots]
# GRDSPEED=              381.453 / Aircraft ground speed [knots]
# LAT_STA =             -58.9283 / Aircraft latitude, start of obs [degree]
# LON_STA =              -166.74 / Aircraft longitude, start of obs [degree]
# LAT_END =             -58.9158 / Aircraft latitude, end of obs [degree]
# LON_END =             -166.773 / Aircraft longitude, end of obs [degree]
# HEADING =             -54.1942 / Aircraft true heading [degree]
# TRACKANG=             -9999.00 / Aircraft track angle [degrees]
# TELESCOP= 'SOFIA   '           / OBSERVATORY NAME
# TELCONF = 'UNKNOWN '           / Telescope configuration
# TELRA   =              18.0084 / SI Boresight RA (ICRS J2000)
# TELDEC  =             -24.0667 / SI Boresight Dec (ICRS J2000)
# TELVPA  =              23.8008 / SI Boresight VPA (ICRS J2000)
# TELEQUI = 'j2000   '           / Equinox of ERF coords (RA/Dec/VPA)
# LASTREW = 'Tue Sep 24 15:03:04 2013' / Time of last rewind (UTC)
# FOCUS_ST=                 903. / Telescope focus [microns], start of obs
# FOCUS_EN=                 903. / Telescope focus [microns], end of obs
# TELEL   =              1.43144 / Telescope elevation [degrees]
# TELXEL  =               1.9025 / Total telescope cross elevation [degrees]
# TELLOS  =              39.8539 / Telescope LOS at observation [degrees]
# TSC-STAT= 'STAB_LOCAL_ONGOING' / TASCU Status at observation end
# FBC-STAT= 'FBC_OFF '           / FBC Status at observation end
# OBSRA   =              11.2681 / RA - requested
# OBSDEC  =             -61.2931 / Dec - requested
# EQUINOX =                2000. / Coordinate equinox for OBSRA and OBSDEC
# ZA_START=              46.8239 / Zenith angle, start of obs
# ZA_END  =              44.6712 / Zenith angle, end of obs
# TRACMODE= 'OFFSET+INERTIAL'    / SOFIA tracking mode
# TRACERR =                    T / Tracking error flag [Y/N]
# CHOPPING=                    F / Chopping flag
# NODDING =                    F / Nodding flag
# MAPPING =                    F / Mapping flag
# SCANNING=                    F / Scanning flag
# INSTRUME= 'GREAT   '           / Instrument
# DATATYPE= 'SPECTRAL'           / Data type
# INSTCFG = 'DUAL_CHANNEL'
# INSTMODE= 'CAL     '           / OBSERVING MODE
# MCCSMODE= 'great_standard'     / MCCS SI Mode (MCCS_SI_04)
# EXPTIME =                  10. / REAL INTEGRATION TIME [s]
# SPECTEL1= 'GRE_L2  '           / First spectral element in use
# SPECTEL2= 'NONE    '           / Second spectral element in use
# CTYPE1  = 'PIXEL   '           / QUANTITY OF 1 AXIS
# FRONTEND= 'GREAT1=1.9THz'      / Name of frontend device.
# BACKEND = 'GREAT_SAFFTS1'      / Name of backend device.
# BANDWID =                2500. / BANDWIDTH (MHZ) OF THE BACKEND
# TSYS    =               -9999. / System temperature.
# FREQRES =               0.1831 / FREQUENCY RESOLUTION
# OBSFREQ =       1900267.933648 / SKY FREQUENCY (MHZ)
# IMAGFREQ=       1898567.933648 / IMAGE FREQUENCY (REST) (MHZ)
# RESTFREQ=            1900536.9 / REST FREQUENCY (MHZ)
# VELDEF  = 'LSR     '           / VELDEF
# VFRAME  =                42.43 / VELOCITY OF TELESCOPE [km/s]
# RVSYS   =                  16.
# CHPFREQ =                   1. / Chop frequency (SOFIA)
# CHPPROF = '2-POINT '           / Chopping profile: 2 or 3 point
# CHPSYM  = 'Contrived'          / Chopping symmetry [SYM, ASYM]
# CHPAMP1 =                   0. / Chop amplitude 1
# CHPAMP2 =                   0. / Chop amplitude 2
# CHPCRSYS= 'erf     '           / MCCS Coordinate system for sky tip, tilt and an
# CHPANGLE=              3.9E-05 / Calculated angle in the sky coord sys reference
# CHPTIP  =                   0. / Calculated tip in the sky coord sys reference f
# CHPTILT =                   0. / Calculated tilt in the sky coord sys reference
# CHPPHASE=                    0 / Chop phase
# NODTIME =                   0. / Nod time
# NODN    =                   1. / Nod cycles
# NODSETL =                   0. / Nod settle time
# NODAMP  =                  45. / Nod amplitude on sky
# NODBEAM = 'a       '           / Current nod beam position
# NODPATT = 'ABAB    '           / Nodding pattern, one cycle
# NODCRSYS= 'erf     '           / Coordinate system for Nod angle
# NODANGLE=               -9999. / Nod angle
# MAPCRSYS= 'J2000   '           / Coordinate system for mapping/scanning.
# MAPNXPOS=                    0 / Number of map positions in X
# MAPNYPOS=                    0 / Number of map positions in Y
# MAPINTX =                   0. / Mapping step interval in X
# MAPINTY =                   0. / Mapping step interval in Y
# SCNRA0  =               -9999. / Start of scan - RA
# SCNDEC0 =               -9999. / Start of scan - Dec
# SCNRAF  =               -9999. / End of scan - RA
# SCNDECF =               -9999. / End of scan - Dec
# SCNRATE =               -9999. / Scan rate
# SCNDIR  =               -9999. / Scan direction
# BZERO   =                    0 / offset data range to that of unsigned long
# BSCALE  =                    1 / default scaling factor
# NEEDZERO=                    F / FLAG FOR NEED OF ZERO/COMB
# FITSVERS= '2.6     '           / KOSMA_CONTROL FITS VERSION/SUBVERSION
# OBSERVAT= 'SOFIA   '           / OBSERVATORY NAME
# TAMBSOFI=                236.8 / Temperature of ambient, SOFIA [K]
# AIRTEMP =               -61.75 / SOFIA Air Temp [C]
# AIRPRESS=             133.6294 / SOFIA Air Press [Torr]
# PRESSALT=           12648.4092 / PRESSURE ALTITUDE [M]
# GPS_ALT =           11915.8512 / GPS ALTITUDE [M]
# SPECTRAL= 'NONE    '           / spectral element(s) in use
# SCANNUM =                 8657 / SCAN NUMBER
# DATE    = '2013-07-24T09:58:45' / Date Observed
# NUMSPEC =                    6 / NUMBER OF ACTIVE SPECTROMETERS
# NAMESPEC= 'SOF-SAFFTS1'        / SPECTROMETER NAME
# LATITUDE=           -58.934522 / TELESCOPE LATITUDE
# LONGITUD=            166.72332 / TELESCOPE LONGITUDE
# SITEALT =            11915.204 / TELESCOPE ALTITUDE [m]
# SOBSMODE= 'HOT     '           / OBSERVING SUB MODE
# DATAQUAL=                    0 / QUALITY INFORMATION
# LST-OBS = '01:18:01'           / OBSERVE LST
# LLOADSN =                 8657 / LAST LOAD SCAN NUMBER
# LFRCASN =                 7059 / LAST FREQUENCY CALIB SCAN NUMBER
# LSKYSN  =                 7520 / LAST SKY MEAS SCAN NUMBER
# AZIMUTH =            214.42026 / AZIMUTH
# ELEVATIO=            40.680008 / ELEVATION
# NODWAIT =                   0. / BLANKING TIME [s]
# AOSLEN  =                0.005 / AOS SINGLE SCAN TIME [s]
# BLANK   =           2147483648 / BLANKING VALUE
# DATAMIN =                   0. / MINIMUM DATA VALUE
# DATAMAX =               65535. / MAXIMUM DATA VALUE
# SUBX    =                   0. / SUBREFLECTOR X
# SUBY    =                   0. / SUBREFLECTOR Y
# SUBZ    =               -3100. / SUBREFLECTOR Z
# SUBI    =                0.005 / SUBREFLECTOR I
# SUBJ    =                 -0.3 / SUBREFLECTOR J
# SUBK    =                   0. / SUBREFLECTOR K
# COORDSYS= 'J2000   '           / COORD SYS ON
# LAMBDA  =            168.81292 / OBS LAM ON
# BETA    =           -61.293056 / OBS BET ON
# COSYDEL = 'J2000   '           / COORD SYS DEL
# LAMDEL  =                   0. / OBS LAM DEL
# BETDEL  =                   0. / OBS BET DEL
# OTADEL  = 'Y       '           / OBSERVE TRUE ANGLE DEL (Y/N)
# COSYOFF = 'J2000   '           / COORD SYS OFF
# LAMOFF  =                 360. / OBS LAM OFF
# BETOFF  =                   0. / OBS BET OFF
# CHOPANGL=                   0. / POSITION ANGLE FOR SKY CHOPPER
# RDLNGTH =                  10. / CHOPPER PHASE TIME LENGTH
# CHOPAMP =                   0. / SKY CHOPPER AMPLITUDE
# CHOPFREQ=                   1. / SKY CHOPPER FREQUENCY
# CHOPCOOR= 'HORIZON '           / SKY CHOPPER COORD SYSTEM
# BORESYS = 'SIRF    '           / BORE SITE SYSTEM
# LINE    = 'CII_U   '           / LINE NAME
# LOFREQ  =       1899417.933648 / LO FREQUENCY (MHZ)
# SYNTH   =         13190.402317 / SYNTHESIZER FREQUENCY (MHZ)
# NUMCHAN =                 8192 / NUMBER OF AOS CHANNELS
# CREFPIX =                4095. / REFERENCE CHANNEL
# CMBBOTPX=               -9999. / LOWEST CHANNEL SPIKE IN COMB
# CMBTOPPX=               -9999. / HIGHEST CHANNEL SPIKE IN COMB
# STARTREF=                4095. / START OF REFERENCE SEARCH
# FREQOFFS=                   0. / FREQUENCY OFFSET
# VELRES  =  -0.0288864523196064 / VELOCITY RESOLUTION
# FREQSWAM=                   0. / FREQUENCY SWITCH AMPLITUDE
# BEFF    =                  0.6 / BEAM EFFICIENCY
# FOEFF   =                 0.95 / FORWARD EFFICIENCY
# GAINIMAG=                  0.5 / GAIN IMAG
# REFRXDX =                   0. / REFERENCE PIXEL OFFSET X [arcsec]
# REFRXDY =                   0. / REFERENCE PIXEL OFFSET Y [arcsec]
# SIGNRXDX=                   1. / SIGN FOR FOCALPLANE TO SKY CONVERSION
# SIGNRXDY=                   1. / SIGN FOR FOCALPLANE TO SKY CONVERSION
# FOCALLEN=             48358.65 / FOCAL LENGTH [mm]
# POSANGLE=                   0. / POSITION ANGLE OF ARRAY [deg]
# BEAMANG =            -173.6351 / REAL BEAM ROTATOR ANGLE [deg]
# ANGLEDIF=            -173.6351 / DIFFERENCE TO CMD ANGLE [deg]
# RXDX    =                   0. / PIXEL OFFSET [arcsec]
# RXDY    =                   0. / PIXEL OFFSET [arcsec]
# THOT    =               295.34 / HOT LOAD TEMP [K]
# TCOLD   =              109.977 / COLD LOAD TEMP [K]
# TAMB    =                236.8 / AMBIENT TEMPERATURE [K]
# PAMB    =             133.6294 / AMBIENT PRESSURE [Torr]
# HAMB    =                  21. / AMBIENT HUMIDITY [0..1]
# SPECTIME=                  10. / SPECIFIED INTEGRATION TIME [s]
# O_BLANK =                    0 / Original BLANK value
# O_BZERO =        2147483648.00 / Original BZERO Value
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# HISTORY: LIST OF KEYWORDS MODIFIED
# HISTORY: HEADSTAT CORRECTED
# HISTORY: LASTREW Tue Sep 24 15:03:04 2013
# HISTORY: TRACKANG -9999.0
# HISTORY: PIPEVERS UNKNOWN
# HISTORY: PIPELINE UNKNOWN
# HISTORY: FILENAME008657_003_GREAT_SAFFTS1.fits Name of host file
# HISTORY: PREVIOUS FILENAME: /data/fits/cycle1_10/008657_003_GREAT_SAFFTS1.fits
# HISTORY: KWDICT "DCS_ICD_revE " SOFIA Keyword dictionary version
# HISTORY: CREATOR level1_reconstruct.pro (v1.1) CREATOR OF FITS FILE
# HISTORY: ORIGIN USRA GREAT - MPIfR/KOSMA
# HISTORY: PLANID 83_0004
# HISTORY: PI: G?sten
# HISTORY: Previous PLANID: 201307_GR_06
# HISTORY
# HISTORY Headers updated by rarneson, 2019-10-07T20:51:59
# HISTORY   INSTCFG: GREAT0=1.4THz MPIfR_1.4THz_Solid- GREAT1=1.9THz MPIfR_1.9THz_
# HISTORY Solid- -> DUAL_CHANNEL
# HISTORY   OBSRA: 0.751206666666667 -> 11.2681
# HISTORY
# FILEREV =                    1 / 2019-10-08T04:07:45Z

# %%
(1900536.9*u.MHz).to(u.THz)
# Out:
# <Quantity 1.9005369 THz>

# %%
15*u.arcsec
# Out:
# <Quantity 15. arcsec>

# %%
u.pixel_scale(u.pixel/15*u.arcsec)
# Out:
# [(Unit("pix"), Unit("15 / arcsec"))]

# %% [markdown]
# ## Herschel

# %%
herfn_1 = '/orange/adamginsburg/higal/Field4_0_Combined_SPIRE_SpirePacsParallel_250_1342214761-1342214762_extd.fits'
herfn_2 = '/orange/adamginsburg/higal/Field4_0_Combined_SPIRE_SpirePacsParallel_350_1342214761-1342214762_extd.fits'
herfn_3 = '/orange/adamginsburg/higal/Field4_0_Combined_SPIRE_SpirePacsParallel_500_1342214761-1342214762_extd.fits'
pacsfn_1 = '/orange/adamginsburg/higal/Field4_0_PACS_SpirePacsParallel_160_1342214761-1342214762_jscanam.fits'
pacsfn_2 = '/orange/adamginsburg/higal/Field4_0_PACS_SpirePacsParallel_70_1342214761-1342214762_jscanam.fits'

# %%
#spitzer_cube = np.array([spitzer_data['I4'][0].data, spitzer_data['I2'][0].data, spitzer_data['I1'][0].data, ])
#fits.PrimaryHDU(data=spitzer_cube, header=spitzer_data['I1'][0].header).writeto(spitzer_cubename, overwrite=True)
her250 = fits.open(herfn_1)

her250data,_ = reproject.reproject_interp(her250[1], spitzer_data['I1'][0].header)
her250data[np.isnan(her250data)] = np.nanmax(her250data)

her70 = fits.open(pacsfn_2)

her70data,_ = reproject.reproject_interp(her70[1], spitzer_data['I1'][0].header)
her70data[np.isnan(her70data)] = np.nanmax(her70data)

her250_cube = np.array([her250data, her70data, mipsdata, ]) #spitzer_data['I4'][0].data])
her250hdu = fits.PrimaryHDU(data=her250_cube, header=spitzer_data['I1'][0].header)
#fits.PrimaryHDU(data=mips_cube, header=spitzer_data['I1'][0].header).writeto(spitzer_cubename.replace("spitzer", "mips"), overwrite=True)

# %%
her = fits.open(herfn_3)
wcs.WCS(her[1].header), her[1].data.shape
# Out:
# (WCS Keywords
#
#  Number of WCS axes: 2
#  CTYPE : 'RA---TAN'  'DEC--TAN'
#  CRVAL : 268.9214150708075  -25.157433046732397
#  CRPIX : 496.0  456.0
#  NAXIS : 893  909,
#  (909, 893))

# %%
her = fits.open(herfn_1)
wcs.WCS(her[1].header), her[1].data.shape
# Out:
# (WCS Keywords
#
#  Number of WCS axes: 2
#  CTYPE : 'RA---TAN'  'DEC--TAN'
#  CRVAL : 268.9214150708075  -25.157433046732397
#  CRPIX : 1156.0  1059.0
#  NAXIS : 2081  2114,
#  (2114, 2081))

# %%
type(her[0].data)
# Out:
# NoneType

# %%
#her[0].header

# %%
def plot_her(her, image, contour_levels):
    #spitz = spitz[0]
    ww = wcs.WCS(her.header)
    
    #ww = wcs.WCS(image.header)
    #print(ww.proj_plane_pixel_scales)
    fig = pl.figure(1, figsize=(8,8))
    #fig.ckf()
    ax = fig.add_subplot(projection=ww.celestial)
    spitzer_display_args=dict(stretch='asinh', min_percent=7, max_percent=99, clip=True)
    #spitz_data = simple_norm(her[1].data, **spitzer_display_args)(her[1].data)
    spitz_data = np.array([simple_norm(x, **spitzer_display_args)(x) for x in her.data])
    

    ax.imshow(spitz_data.T.swapaxes(0,1))
    lims = ax.axis()
    #ax.contour(image, transform=ax.get_transform(image.wcs.celestial), levels=contour_levels, colors='w', linewidths=[1.5])
    #ax.coords['ra'].set_axislabel('Right Ascension')
    #ax.coords['dec'].set_axislabel('Declination')
    
    c_icrs = coord.SkyCoord(ra=5.4*u.degree, dec=-0.4*u.degree, frame='icrs')
    
    #ax.scatter(304.29243304, -55.81833393, transform=ax.get_transform(image.wcs.celestial), s=s,
    #       edgecolor='cyan')
    #ax.scatter(5.4, -0.4, transform=ax.get_transform('galactic'), s=300,
    #       edgecolor='white', facecolor='none')
    
    reg = regions.RectangleSkyRegion(center=SkyCoord(5.378*u.deg, -0.408*u.deg, frame='galactic'), width=720*u.arcsec, height=150*u.arcsec, angle=0*u.deg)
    preg = reg.to_pixel(wcs.WCS(spitz.header).celestial)
    preg.plot(edgecolor='yellow')

    ax.coords['glon'].set_axislabel('Galactic Longitude')
    ax.coords['glat'].set_axislabel('Galactic Latitude')
    
    return ax

# %%
from astropy import stats, convolution, wcs, coordinates

loc1 = '/orange/adamginsburg/cmz/g5/G5/sum/spw17_12CO/g5.mom0.smK.tot.12CO.spw17.im/'
# g5.12CO.spw17.im/ # g5.mom0.smK.tot.12CO.spw17.im/
cube = SpectralCube.read(loc1, format='casa_image')
#pbv,_ = reproject.reproject_interp(pb[10].hdu, fh[0].header)

                # 10th channel is arbitrary but avoids edge channel
#data = fh[0].data * pbv
data = cube[0].hdu.data

std = stats.mad_std(data, ignore_nan=True)
levels = np.array([3, 5, 10, 20, 30])*std

m0 = Projection(data, wcs=cube.wcs.celestial)
contour_levels = np.logspace(0, 5, num=25)

# %%
ax = plot_her(her250hdu, m0, contour_levels)
#ax.axis([250,330,580,680])

# %%
pos = (5.4*u.deg, -0.4*u.deg)
c_icrs = coord.SkyCoord(ra=5.4*u.degree, dec=-0.4*u.degree, frame='icrs')

# %%
from astropy import stats, convolution, wcs, coordinates

#wcs = wcs.WCS(her[0].header)
data = her[1].data

cutout = Cutout2D(data, c_icrs, (5, 5), wcs=wcs, mode='partial')
plt.imshow(cutout.data, origin='lower')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /scratch/local/25260084/ipykernel_15927/771363216.py in <module>
#       4 data = her[1].data
#       5
# ----> 6 cutout = Cutout2D(data, c_icrs, (5, 5), wcs=wcs, mode='partial')
#       7 plt.imshow(cutout.data, origin='lower')
#
# /blue/adamginsburg/adamginsburg/repos/astropy/astropy/nddata/utils.py in __init__(self, data, position, size, wcs, mode, fill_value, copy)
#     527                 raise ValueError('wcs must be input if position is a '
#     528                                  'SkyCoord')
# --> 529             position = skycoord_to_pixel(position, wcs, mode='all')  # (x, y)
#     530
#     531         if np.isscalar(size):
#
# /blue/adamginsburg/adamginsburg/repos/astropy/astropy/wcs/utils.py in skycoord_to_pixel(coords, wcs, origin, mode)
#     528     """
#     529
# --> 530     if _has_distortion(wcs) and wcs.naxis != 2:
#     531         raise ValueError("Can only handle WCS with distortions for 2-dimensional WCS")
#     532
#
# /blue/adamginsburg/adamginsburg/repos/astropy/astropy/wcs/utils.py in _has_distortion(wcs)
#     495     `True` if contains any SIP or image distortion components.
#     496     """
# --> 497     return any(getattr(wcs, dist_attr) is not None
#     498                for dist_attr in ['cpdis1', 'cpdis2', 'det2im1', 'det2im2', 'sip'])
#     499
#
# /blue/adamginsburg/adamginsburg/repos/astropy/astropy/wcs/utils.py in <genexpr>(.0)
#     495     `True` if contains any SIP or image distortion components.
#     496     """
# --> 497     return any(getattr(wcs, dist_attr) is not None
#     498                for dist_attr in ['cpdis1', 'cpdis2', 'det2im1', 'det2im2', 'sip'])
#     499
#
# AttributeError: module 'astropy.wcs' has no attribute 'cpdis1'

# %%
pacs = fits.open(pacsfn_1)

# %%
plot_her(pacs, m0, contour_levels)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /scratch/local/23116053/ipykernel_57529/1071710542.py in <module>
# ----> 1 plot_her(pacs, m0, contour_levels)
#
# /scratch/local/23116053/ipykernel_57529/435959712.py in plot_her(her, image, contour_levels)
#       7     fig = pl.figure(1, figsize=(8,8))
#       8     #fig.ckf()
# ----> 9     ax = fig.add_subplot(projection=ww.celestial)
#      10     spitzer_display_args=dict(stretch='asinh', min_percent=7, max_percent=90., clip=True)
#      11     #spitz_data = simple_norm(spitz.data, **spitzer_display_args)(spitz.data)
#
# /orange/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     770             projection_class, pkw = self._process_projection_requirements(
#     771                 *args, **kwargs)
# --> 772             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773             key = (projection_class, pkw)
#     774         return self._add_axes_internal(ax, key)
#
# /orange/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      32         """
#      33         # _axes_class is set in the subplot_class_factory
# ---> 34         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35         # This will also update the axes position.
#      36         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# /blue/adamginsburg/adamginsburg/repos/astropy/astropy/visualization/wcsaxes/core.py in __init__(self, fig, rect, wcs, transform, coord_meta, transData, slices, frame_class, **kwargs)
#     117             self.transData = transData
#     118
# --> 119         self.reset_wcs(wcs=wcs, slices=slices, transform=transform, coord_meta=coord_meta)
#     120         self._hide_parent_artists()
#     121         self.format_coord = self._display_world_coords
#
# /blue/adamginsburg/adamginsburg/repos/astropy/astropy/visualization/wcsaxes/core.py in reset_wcs(self, wcs, slices, transform, coord_meta)
#     367         if self.wcs is not None:
#     368
# --> 369             transform, coord_meta = transform_coord_meta_from_wcs(self.wcs, self.frame_class, slices=slices)
#     370
#     371         self.coords = CoordinatesMap(self,
#
# /blue/adamginsburg/adamginsburg/repos/astropy/astropy/visualization/wcsaxes/wcsapi.py in transform_coord_meta_from_wcs(wcs, frame_class, slices)
#     151
#     152         for i, spine_name in enumerate('bltr'):
# --> 153             pos = np.nonzero(m[:, i % 2])[0]
#     154             # If all the axes we have are correlated with each other and we
#     155             # have inverted the axes, then we need to reverse the index so we
#
# IndexError: index 0 is out of bounds for axis 1 with size 0

# %%
loc_sio = '/orange/adamginsburg/cmz/g5/G5/sum/spw27_SiO/g5.mom0.smK.tot.SiO.spw27.im/'

sio = SpectralCube.read(loc_sio, format='casa_image')

sio.quicklook()
# Out:
# /blue/adamginsburg/adamginsburg/repos/casa-formats-io/casa_formats_io/casa_dask.py:247: RuntimeWarning: divide by zero encountered in long_scalars
#   factors = [f for f in range(stacks[dim] + 1) if stacks[dim] % f == 0]
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.io.core]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /scratch/local/24384615/ipykernel_95181/2940589514.py in <module>
#       3 sio = SpectralCube.read(loc_sio, format='casa_image')
#       4
# ----> 5 sio.quicklook()
#
# AttributeError: 'DaskSpectralCube' object has no attribute 'quicklook'

# %%
with quantity_support():
    plt.figure()
    ax = plt.subplot(111, projection=sio.wcs.celestial)
    plt.imshow(sio[0].value)
    cbar = plt.colorbar()
    cbar.set_label('K')
    ax.coords['glon'].set_axislabel('Galactic Longitude')
    ax.coords['glat'].set_axislabel('Galactic Latitude')
    plt.savefig('plots/sio_m0.pdf')
