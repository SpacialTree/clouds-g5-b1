# %%
from spectral_cube import SpectralCube
from pvextractor import extract_pv_slice, Path
import pylab as pl
import numpy as np
from astropy.visualization import quantity_support
from astropy import units as u
from astropy import wcs
from matplotlib.colors import LogNorm
from astropy.visualization.stretch import SinhStretch
from astropy.visualization import simple_norm
import matplotlib.pyplot as plt
from astropy.utils import data
#from cycler import cycler
#from itertools import cycle
from scipy.stats import ks_2samp
from scipy.optimize import fsolve
from spectral_cube import Projection
from astropy.coordinates import SkyCoord
from astropy.coordinates import ICRS, Galactic, FK4, FK5  # Low-level frames
from astropy.coordinates import Angle, Latitude, Longitude  # Angles
from scipy.interpolate import interp1d
# Out:
# fatal: detected dubious ownership in repository at '/blue/adamginsburg/adamginsburg/repos/dask'
# To add an exception for this directory, call:
#
# 	git config --global --add safe.directory /blue/adamginsburg/adamginsburg/repos/dask

# %%
import warnings

def fxn():
    warnings.warn("WCSWarning", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %% [markdown]
# # Data

# %%
a_fixednames =['/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.12CO.spw17.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.Ha.spw19.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.CH3OH.spw21.fits',
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.H2CO.spw23.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.H2CO.spw25.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.SiO.spw27.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.13CO.spw29.fits', 
               '/home/savannahgramze/orange_link/adamginsburg/cmz/g5/G5/a/TP/2018.1.00862.S/galreprojected/g5a.C18O.spw31.fits' 
               ]
cube_17 = SpectralCube.read(a_fixednames[0]).with_spectral_unit(u.km/u.s, velocity_convention='radio')#.with_spectral_unit(u.GHz, velocity_convention='radio')
#cube_21 = SpectralCube.read(a_fixednames[2]).with_spectral_unit(u.km/u.s, velocity_convention='radio')#.with_spectral_unit(u.GHz, velocity_convention='radio')
#cube_23 = SpectralCube.read(a_fixednames[3]).with_spectral_unit(u.km/u.s, velocity_convention='radio')#.with_spectral_unit(u.GHz, velocity_convention='radio')
#cube_25 = SpectralCube.read(a_fixednames[4]).with_spectral_unit(u.km/u.s, velocity_convention='radio')#.with_spectral_unit(u.GHz, velocity_convention='radio')
#cube_27 = SpectralCube.read(a_fixednames[5]).with_spectral_unit(u.km/u.s, velocity_convention='radio')#.with_spectral_unit(u.GHz, velocity_convention='radio')
cube_29 = SpectralCube.read(a_fixednames[6]).with_spectral_unit(u.km/u.s, velocity_convention='radio')#.with_spectral_unit(u.GHz, velocity_convention='radio')
cube_31 = SpectralCube.read(a_fixednames[7]).with_spectral_unit(u.km/u.s, velocity_convention='radio')#.with_spectral_unit(u.GHz, velocity_convention='radio')

# %%
def noise_mask(cube, vmin, vmax, level):
    noise = cube.with_spectral_unit(u.km/u.s, velocity_convention='radio').spectral_slab(vmin, vmax).std(axis=0)
    peak = cube.max(axis=0)
    spatial_mask = peak > level * noise
    return spatial_mask

def noise_mask_slab(cube, vmin, vmax, level, cut1, cut2):
    noise = cube.with_spectral_unit(u.km/u.s, velocity_convention='radio').spectral_slab(vmin, vmax).std(axis=0)
    peak = cube.spectral_slab(cut1, cut2).max(axis=0)
    spatial_mask = peak > level * noise
    return spatial_mask

# %%
mask_17 = noise_mask(cube_17, -100*u.km/u.second, -50 *u.km/u.second, 5)
mask_29 = noise_mask(cube_29, -100*u.km/u.second, -50 *u.km/u.second, 5)
mask_31 = noise_mask(cube_31, -100*u.km/u.second, -50 *u.km/u.second, 5)
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.std at 0x2b28eb52c160>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /orange/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1878: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2b28eb52c4c0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: All-NaN slice encountered
#   out = function(self._get_filled_data(fill=fill,
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.std at 0x2b28eb52c160>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /orange/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1878: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2b28eb52c4c0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: All-NaN slice encountered
#   out = function(self._get_filled_data(fill=fill,
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.std at 0x2b28eb52c160>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /orange/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1878: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2b28eb52c4c0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: All-NaN slice encountered
#   out = function(self._get_filled_data(fill=fill,

# %% [markdown]
# # Cube Ratios

# %%
cube_17.shape
# Out:
# (2048, 63, 274)

# %%
cube_29.shape
# Out:
# (1024, 61, 262)

# %%
# cube.spectral_axis is np.arange(0,10,0.5) for this example
#new_axis = np.arange(0,10,2)*u.km/u.s
#fwhm_factor = np.sqrt(8*np.log(2))
#
#smcube = cube.spectral_smooth(Gaussian1DKernel(4/fwhm_factor))
#interp_Cube = smcube.spectral_interpolate(new_axis,
#                                          suppress_smooth_warning=True)

# %%
cube_29.spectral_axis
# Out:
# <Quantity [-120.03226323, -119.70016674, -119.36807026, ...,  219.0382489 ,
#             219.37034539,  219.70244187] km / s>

# %%
interp_cube17 = cube_17.spectral_interpolate(cube_29.spectral_axis)
# Out:
# WARNING: SmoothingWarning: Input grid has too small a spacing. The data should be smoothed prior to resampling. [spectral_cube.spectral_cube]

# %%
reproj_cube17 = interp_cube17.reproject(cube_29.header)
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.reproject at 0x2b28eb5325e0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]

# %%
mask_rep17 = noise_mask(reproj_cube17, -100*u.km/u.second, -50 *u.km/u.second, 5)
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.std at 0x2b28eb52c160>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /orange/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1878: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.max at 0x2b28eb52c4c0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: All-NaN slice encountered
#   out = function(self._get_filled_data(fill=fill,

# %%
ratio_cube1729 = reproj_cube17.with_mask(mask_rep17) / cube_29.with_mask(mask_29)
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube._cube_on_cube_operation at 0x2b28eb5300d0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.to at 0x2b28eb532430>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]

# %%
ratio_cube1729.mean(axis=1).quicklook()
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x2b28eb52bee0>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /blue/adamginsburg/adamginsburg/repos/spectral-cube/spectral_cube/spectral_cube.py:439: RuntimeWarning: Mean of empty slice
#   out = function(self._get_filled_data(fill=fill,
# WARNING: WCSWarning: Slicing across a celestial axis results in an invalid WCS, so the celestial projection (TAN) is being removed.  The WCS indices being kept were [0 2]. [spectral_cube.wcs_utils]
# INFO: Auto-setting vmin to -1.366e+03 [aplpy.core]
# INFO: Auto-setting vmax to  1.667e+03 [aplpy.core]

# %%
0.016*5
# Out:
# 0.08

# %%
#ratio_cube1729[ratio_cube1729<1] = 0
#tes_rat = np.zeros(ratio_cube1729.shape)
#tes_rat*(ratio_cube1729>0.08)
ratio_cube1729 = ratio_cube1729.with_mask(ratio_cube1729>0.08).with_mask(ratio_cube1729<100)#.mean(axis=1).quicklook()

# %%
cube_29.spectral_slab(-100*u.km/u.second, -50*u.km/u.second).std(axis=0).quicklook()
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.std at 0x2b28eb52c160>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /orange/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1878: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# INFO: Auto-setting vmin to  7.882e-03 [aplpy.core]
# INFO: Auto-setting vmax to  1.747e-02 [aplpy.core]

# %%
cube_29[1000].quicklook()
# Out:
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# INFO: Auto-setting vmin to -3.871e-02 [aplpy.core]
# INFO: Auto-setting vmax to  5.143e-02 [aplpy.core]

# %% [markdown]
# # Interpolation

# %%
# Use linpace to find an array of observed ratios between 1-40
# interpolate
# make ratio cubes
# set tau = 0 when 13CO is not detected
# find that the pixels at ~10km/s are optically thick
# what fraction are at each optical depth? how much of the cloud is truly optically thin/thick?
# make a histogram of the tau values

# %%
def funct(tau, A): # = R
    #A = 30
    return (1-np.e**(-tau))/(1-np.e**(-tau/A))

def F_25(tau, R=20, A=25):
    return R - funct(tau, A)

def piecewise_25(val, inter, mini=1, maxi=25):
    gel = np.zeros(val.shape)
    for g in range(len(gel)):
        if np.less(val[g], mini):
            #return 0
            gel[g] = 0
        elif np.greater(val[g], maxi):
            #return 0
            gel[g] = 0
        else:
            #return inter(val)
            #print('heyo')
            try:
                gel[g] = inter(val[g])
            except: 
                print(val[g])
                gel[g] = 0
    return gel

# %%
R_25 = np.linspace(1, 25, num=100)
ones = np.ones(100)
tau_f25 = interp1d(R_25, fsolve(F_25, ones, R_25))
# Out:
# /orange/adamginsburg/miniconda3/envs/python39/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
tau_f25([[25, 20], [2, 6]])
# Out:
# array([[-9.86926801e-08,  4.85305243e-01],
#        [ 1.73816849e+01,  4.50476021e+00]])

# %%
piecewise_25(np.array([2, 6]), tau_f25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /scratch/local/55753633/ipykernel_13647/3861619150.py in <module>
# ----> 1 piecewise_25(np.array([2, 6]), tau_f25)
#
# /scratch/local/55753633/ipykernel_13647/488073728.py in piecewise_25(val, inter, mini, maxi)
#       8 def piecewise_25(val, inter, mini=1, maxi=25):
#       9     gel = np.zeros(val.shape)
# ---> 10     if np.less(val, mini):
#      11         return 0
#      12     elif np.greater(val, maxi):
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
def reshape_arr(chan):
    s1 = chan.shape
    #print(s1)
    size = s1[0]*s1[1]
    reshaped = np.array(chan).reshape(size)
    s2 = reshaped.shape
    return reshaped#, s1
    #print(s2)
    #back_shape = reshaped.reshape(s1)
    #s3 = back_shape.shape
    #print(s3)
    #print(np.count_nonzero(chan-back_shape))
    #plt.imshow(chan-back_shape)
    #return (chan-back_shape)
    
def shape_back_arr(reshaped, s1):
    back_shape = reshaped.reshape(s1)
    return back_shape

# %%
chan = np.array(ratio_cube1729.hdu.data)[100]

#for chan in range(ratio_cube1729.shape[0]): 
    #print(chan)

# %%
plt.imshow(reshape_arr(chan))
plt.colorbar()
# Out:
# (61, 262)
# (15982,)
# (61, 262)
# 8955

# %%
ratio_cube1729.shape
# Out:
# (1024, 61, 262)

# %%
tau_cube = np.zeros(ratio_cube1729.shape)
cube_arr = np.array(ratio_cube1729.hdu.data)
for ch in range(ratio_cube1729.shape[0]):
    chan = cube_arr[ch]
    long = reshape_arr(chan)
    tau_chan = piecewise_25(long, tau_f25)
    tau_cube[ch] = shape_back_arr(tau_chan, chan.shape)

# %%
plt.imshow(tau_cube[300])

# %%
plt.imshow(np.nansum(tau_cube, axis=1))
plt.colorbar()

# %%
SpectralCube(tau_cube, ratio_cube1729.wcs).write('/orange/adamginsburg/cmz/g5/code/plots/tau_cube.fits')
# Out:
# SpectralCube with shape=(1024, 61, 262):
#  n_x:    262  type_x: GLON-TAN  unit_x: deg    range:     5.271025 deg:    5.483882 deg
#  n_y:     61  type_y: GLAT-TAN  unit_y: deg    range:    -0.432197 deg:   -0.383266 deg
#  n_s:   1024  type_s: VRAD      unit_s: m / s  range:  -120032.263 m / s:  219702.442 m / s

# %%
ls /orange/adamginsburg/cmz/g5/code/plots/
# Out:
# 160micron.png               mom0_17.fits          pvdiagram_12CO_hot.pdf
# Field1_spec.pdf             mom0_17.pdf           pvdiagram_13CO.fits
# Field2_spec.pdf             mom0_21.pdf           pvdiagram_13CO.pdf
# H30a.spec.pdf               mom0_23-new.pdf       pvdiagram_13CO.png
# adjustedspectrum.pdf        mom0_23.pdf           pvdiagram_C18O.fits
# alt_spitz.pdf               mom0_25-new.pdf       pvdiagram_C18O.pdf
# alt_spitz.png               mom0_25.fits          pvdiagram_C18O.png
# atlasgal.png                mom0_25.pdf           pvdiagram_CH3OH.fits
# bolocam.png                 mom0_27-new.pdf       pvdiagram_CH3OH.pdf
# chemistry_ratio.pdf         mom0_27.pdf           pvdiagram_CH3OH.png
# chemistry_ratio.png         mom0_29-new.pdf       pvdiagram_H2CO_spw23.fits
# col_SiO.fits                mom0_29.pdf           pvdiagram_H2CO_spw23.pdf
# despoticcombo.pdf           mom0_31-new.pdf       pvdiagram_H2CO_spw23.png
# despotich2co.pdf            mom0_31.pdf           pvdiagram_H2CO_spw25.fits
# despoticsio.pdf             mom0_G5a_17-new.pdf   pvdiagram_H2CO_spw25.pdf
# despoticsio.png             mom0_G5a_17.pdf       pvdiagram_H2CO_spw25.png
# dustsed.pdf                 mom0_G5b_17-new.pdf   pvdiagram_HC3N.pdf
# fullspectrum.pdf            mom0_G5b_17.pdf       pvdiagram_SiO.fits
# her250.pdf                  mom1_17-new.pdf       pvdiagram_SiO.pdf
# her250.png                  mom1_17.pdf           pvdiagram_SiO.png
# isoratios.pdf               mom2_17-new.pdf       pvdiagram_afmhot_12CO.png
# isotopologue.pdf            mom2_17.pdf           pvdiagram_inferno_12CO.pdf
# isotopologue_ratio.pdf      mom2_25.fits          pvdiagram_inferno_12CO.png
# isotopologue_ratio.png      opa1213.fits          ratio.pdf
# isotopologue_updated.pdf    opa1213_30.fits       sed.pdf
# kpvdiagram_12CO.fits        opa1213_40.fits       sed.png
# kpvdiagram_13CO.fits        opa1218.fits          sio_m0.pdf
# kpvdiagram_C18O.fits        opa1218_275.fits      spitzer_1.pdf
# kpvdiagram_CH3OH.fits       opa1218_350.fits      spitzer_2.pdf
# kpvdiagram_H2CO_spw23.fits  opa1218_440.fits      spitzer_2.png
# kpvdiagram_H2CO_spw25.fits  opacity_est.pdf       tau_cube.fits
# kpvdiagram_SiO.fits         opacity_est_1213.pdf  temperature.pdf
# lineratios.pdf              opacity_est_1218.pdf  temperature.png
# masshist.pdf                persubtraction.pdf    temperature_a.pdf
# masstable.txt               pgplot.data.txt       temperature_b.pdf
# methanol_cubes.ipynb        pgplot.ps             temphisst-update.pdf
# mom0_17-new.pdf             pvdiagram_12CO.fits   temphist.pdf
# mom0_17-reg.pdf             pvdiagram_12CO.pdf    trms.pdf
